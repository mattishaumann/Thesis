# %% [markdown]
# # Antispiegel
# Load Antispiegel CSV files and create a DataFrame named `df`.

# %%
from pathlib import Path
import pandas as pd

def resolve_project_root() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in (cwd, cwd.parent):
        if (candidate / "data" / "raw" / "Alternative Medien").exists():
            return candidate
    raise FileNotFoundError("Could not locate project root containing data/raw/Alternative Medien")

def read_csv_resilient(csv_path: Path) -> pd.DataFrame:
    for encoding in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            return pd.read_csv(
                csv_path,
                encoding=encoding,
                low_memory=False,
                on_bad_lines="skip",
            )
        except Exception:
            pass

    for encoding in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            return pd.read_csv(
                csv_path,
                encoding=encoding,
                sep=None,
                engine="python",
                low_memory=False,
                on_bad_lines="skip",
            )
        except Exception:
            pass

    raise ValueError(f"Could not read: {csv_path}")

PROJECT_ROOT = resolve_project_root()
BASE_DIR = PROJECT_ROOT / "data" / "raw" / "Alternative Medien"

SOURCE_NAME = "Antispiegel"
SOURCE_DIR = BASE_DIR / SOURCE_NAME
csv_files = sorted(SOURCE_DIR.rglob("*.csv"))

parts = []
for csv_file in csv_files:
    part = read_csv_resilient(csv_file)
    part["source"] = SOURCE_NAME
    part["source_file"] = csv_file.name
    parts.append(part)

df = pd.concat(parts, ignore_index=True, sort=False) if parts else pd.DataFrame()

print(f"Loaded {len(df)} rows from {len(csv_files)} file(s) in {SOURCE_DIR}")
pd.reset_option('display.max_colwidth')
df.head()
# Out:
# Loaded 914 rows from 307 file(s) in /Users/MattisHaumann/Dev/Thesis/data/raw/Alternative Medien/Antispiegel
#          Date                                              Title  \
# 0  2025-04-10  Was das Krisenbarometer Gold über Trumps Zoll-...
# 1  2025-04-10  Hat die LGBT-Propaganda nur den Zweck, einen g...
# 2  2025-04-10                    Will die EU Krieg oder Frieden?
# 3  2025-04-11            Sind die Russen zu dumm für Propaganda?
# 4  2025-04-11  Mit welchem Trick Paris und London Europa in e...
#
#                                              Summary  \
# 0  Die Goldpreise brechen Rekorde und derzeit ver...
# 1  Ich bin auf einen sehr interessanten Artikel g...
# 2  Die große Frage ist derzeit nicht nur, ob die ...
# 3  Diese Woche habe ich einen Artikel über die "W...
# 4  London und Paris haben anscheinend einen Weg g...
#
#                                                 Text  \
# 0  Zeichen auf Sturm\nWas das Krisenbarometer Gol...
# 1  Achtung, Verschwörungstheorie!\nHat die LGBT-P...
# 2  Ukraine\nWill die EU Krieg oder Frieden?\nDie ...
# 3  Freitagsgedanken\nSind die Russen zu dumm für ...
# 4  Ukraine-Krieg\nMit welchem Trick Paris und Lon...
#
#                                             Comments  \
# 0  Egal Anders sagt:\n10. April 2025 um 11:21 Uhr...
# 1  TonyOdessa sagt:\n10. April 2025 um 07:11 Uhr\...
# 2  Grobmotoriker sagt:\n10. April 2025 um 05:31 U...
# 3  VladTepes sagt:\n11. April 2025 um 19:04 Uhr\n...
# 4  TonyOdessa sagt:\n11. April 2025 um 15:40 Uhr\...
#
#                                                  URL  \
# 0  https://anti-spiegel.ru/2025/was-das-krisenbar...
# 1  https://anti-spiegel.ru/2025/hat-die-lgbt-prop...
# 2  https://anti-spiegel.ru/2025/will-die-eu-krieg...
# 3  https://anti-spiegel.ru/2025/sind-die-russen-z...
# 4  https://anti-spiegel.ru/2025/mit-welchem-trick...
#
#                                            Full_Text       source  \
# 0  Was das Krisenbarometer Gold über Trumps Zoll-...  Antispiegel
# 1  Hat die LGBT-Propaganda nur den Zweck, einen g...  Antispiegel
# 2  Will die EU Krieg oder Frieden? Die große Frag...  Antispiegel
# 3  Sind die Russen zu dumm für Propaganda? Diese ...  Antispiegel
# 4  Mit welchem Trick Paris und London Europa in e...  Antispiegel
#
#                                source_file
# 0  antispiegel_tagesartikel_2025-04-11.csv
# 1  antispiegel_tagesartikel_2025-04-11.csv
# 2  antispiegel_tagesartikel_2025-04-11.csv
# 3  antispiegel_tagesartikel_2025-04-12.csv
# 4  antispiegel_tagesartikel_2025-04-12.csv

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 914 entries, 0 to 913
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         914 non-null    object
#  1   Title        914 non-null    object
#  2   Summary      913 non-null    object
#  3   Text         914 non-null    object
#  4   Comments     236 non-null    object
#  5   URL          914 non-null    object
#  6   Full_Text    914 non-null    object
#  7   source       914 non-null    str
#  8   source_file  914 non-null    str
# dtypes: object(7), str(2)
# memory usage: 64.4+ KB

# %%
df = df.drop(columns=['Full_Text', 'Comments'])
df.head(1)
# Out:
#          Date                                              Title  \
# 0  2025-04-10  Was das Krisenbarometer Gold über Trumps Zoll-...
#
#                                              Summary  \
# 0  Die Goldpreise brechen Rekorde und derzeit ver...
#
#                                                 Text  \
# 0  Zeichen auf Sturm\nWas das Krisenbarometer Gol...
#
#                                                  URL       source  \
# 0  https://anti-spiegel.ru/2025/was-das-krisenbar...  Antispiegel
#
#                                source_file
# 0  antispiegel_tagesartikel_2025-04-11.csv

# %% [markdown]
# Cut off comments at the end and title etc. at the beginning

# %%
df['Text'] = df['Text'].str.split('Teile diesen Beitrag').str[0].str.strip()

# %%
df['Text'].str.len().mean()
# Out:
# 10024.2647702407

# %%
import re

def clean_text(text):
    if pd.isna(text):
        return text
    # Match date pattern followed by time ending with "Uhr" at the start of the article
    # Pattern: day. month year time Uhr (e.g., "10. Februar 2026 20:36 Uhr")
    pattern = r'^.*?\d{1,2}\.\s+\w+\s+\d{4}\s+\d{1,2}:\d{2}\s+Uhr\s*'
    cleaned = re.sub(pattern, '', text, count=1, flags=re.DOTALL)
    return cleaned.strip()

df['Text'] = df['Text'].apply(clean_text)
df.head(2)
# Out:
#          Date                                              Title  \
# 0  2025-04-10  Was das Krisenbarometer Gold über Trumps Zoll-...
# 1  2025-04-10  Hat die LGBT-Propaganda nur den Zweck, einen g...
#
#                                              Summary  \
# 0  Die Goldpreise brechen Rekorde und derzeit ver...
# 1  Ich bin auf einen sehr interessanten Artikel g...
#
#                                                 Text  \
# 0  Die Finanzmärkte gehen gerade durch eine Krise...
# 1  Ich bin am Mittwoch auf einen Artikel von Dagm...
#
#                                                  URL       source  \
# 0  https://anti-spiegel.ru/2025/was-das-krisenbar...  Antispiegel
# 1  https://anti-spiegel.ru/2025/hat-die-lgbt-prop...  Antispiegel
#
#                                source_file
# 0  antispiegel_tagesartikel_2025-04-11.csv
# 1  antispiegel_tagesartikel_2025-04-11.csv

# %%
# check length to verify how much was on average deleted at the beginning
df['Text'].str.len().mean()
# Out:
# 9669.411378555798

# %%
df['Text'] = df['Text'].str.replace('\n', ' ', regex=False)
df.head(2)
# Out:
#          Date                                              Title  \
# 0  2025-04-10  Was das Krisenbarometer Gold über Trumps Zoll-...
# 1  2025-04-10  Hat die LGBT-Propaganda nur den Zweck, einen g...
#
#                                              Summary  \
# 0  Die Goldpreise brechen Rekorde und derzeit ver...
# 1  Ich bin auf einen sehr interessanten Artikel g...
#
#                                                 Text  \
# 0  Die Finanzmärkte gehen gerade durch eine Krise...
# 1  Ich bin am Mittwoch auf einen Artikel von Dagm...
#
#                                                  URL       source  \
# 0  https://anti-spiegel.ru/2025/was-das-krisenbar...  Antispiegel
# 1  https://anti-spiegel.ru/2025/hat-die-lgbt-prop...  Antispiegel
#
#                                source_file
# 0  antispiegel_tagesartikel_2025-04-11.csv
# 1  antispiegel_tagesartikel_2025-04-11.csv

# %% [markdown]
# Date

# %%
# Extract relevant time 
df_clean = df.copy()

start, end = "2025-08-01", "2026-01-31"

dates = pd.to_datetime(df_clean["Date"], errors="coerce")
mask = (dates >= pd.Timestamp(start)) & (dates <= pd.Timestamp(end))

df_clean = df_clean.loc[mask].copy()
df_clean["Date"] = pd.to_datetime(df_clean["Date"], errors="coerce")

print(f"Rows in selected period: {len(df_clean)}")
df_clean.sort_values("Date").head()
# Out:
# Rows in selected period: 613
#           Date                                              Title  \
# 269 2025-08-01  Bereitet der Westen die Entmachtung oder sogar...
# 270 2025-08-01  EU-Kommission hat Textnachrichten zum Kauf der...
# 271 2025-08-01  Wahlkommission rechtfertigt Einmischung der EU...
# 272 2025-08-02  Fordert Russland wirklich die Vernichtung alle...
# 273 2025-08-02  Der Spiegel macht mal wieder Berichterstattung...
#
#                                                Summary  \
# 269  Der Streit um das NABU hat gezeigt, dass der W...
# 270  Die New York Times berichtet über ein Schreibe...
# 271  Die Chefin der moldawischen Wahlkommission hat...
# 272  Die Überschrift des RIA-Artikels "Niemand darf...
# 273  Es ist immer wieder erstaunlich, mit welcher V...
#
#                                                   Text  \
# 269  Der Streit um das Nationale Anti-Korruptionsbü...
# 270  Die New York Times versucht seit langem vor Ge...
# 271  Ende September stehen in Moldawien Parlamentsw...
# 272  Ich bin auf die Geschichte zuerst bei RT-DE ge...
# 273  Wer auch nicht-westliche Medien liest, der ist...
#
#                                                    URL       source  \
# 269  https://anti-spiegel.ru/2025/bereitet-der-west...  Antispiegel
# 270  https://anti-spiegel.ru/2025/eu-kommission-hat...  Antispiegel
# 271  https://anti-spiegel.ru/2025/wahlkommission-re...  Antispiegel
# 272  https://anti-spiegel.ru/2025/fordert-russland-...  Antispiegel
# 273  https://anti-spiegel.ru/2025/der-spiegel-macht...  Antispiegel
#
#                                  source_file
# 269  antispiegel_tagesartikel_2025-08-02.csv
# 270  antispiegel_tagesartikel_2025-08-02.csv
# 271  antispiegel_tagesartikel_2025-08-02.csv
# 272  antispiegel_tagesartikel_2025-08-03.csv
# 273  antispiegel_tagesartikel_2025-08-03.csv

# %%
df_clean['Date'].min()
# Out:
# Timestamp('2025-08-01 00:00:00')

# %%
df_clean['Date'].max()
# Out:
# Timestamp('2026-01-31 00:00:00')

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 613 entries, 269 to 881
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         613 non-null    datetime64[us]
#  1   Title        613 non-null    object
#  2   Summary      612 non-null    object
#  3   Text         613 non-null    str
#  4   URL          613 non-null    object
#  5   source       613 non-null    str
#  6   source_file  613 non-null    str
# dtypes: datetime64[us](1), object(3), str(3)
# memory usage: 33.7+ KB

# %% [markdown]
# Check duplicates

# %%
# Check duplicates by URL
url_duplicates = df_clean[df_clean.duplicated(subset=['URL'], keep=False)]
print(f"Duplicate URLs: {len(url_duplicates)} rows ({url_duplicates['URL'].nunique()} unique URLs)")

# Check duplicates by Title
title_duplicates = df_clean[df_clean.duplicated(subset=['Title'], keep=False)]
print(f"Duplicate Titles: {len(title_duplicates)} rows ({title_duplicates['Title'].nunique()} unique Titles)")

# Check duplicates by Text
text_duplicates = df_clean[df_clean.duplicated(subset=['Text'], keep=False)]
print(f"Duplicate Text: {len(text_duplicates)} rows")

# Show duplicate URLs if any
if len(url_duplicates) > 0:
    print("\n--- Sample Duplicate URLs ---")
    print(url_duplicates[['Date', 'Title', 'URL']].head(10))
# Out:
# Duplicate URLs: 0 rows (0 unique URLs)
# Duplicate Titles: 0 rows (0 unique Titles)
# Duplicate Text: 0 rows

# %%
# Remove articles where Title contains "Tacheles #" as this is podcast advertismenet
df_clean = df_clean[~df_clean["Title"].str.contains("Tacheles #", na=False)]
print(f"Rows after removing 'Tacheles #' articles: {len(df_clean):,}")
# Out:
# Rows after removing 'Tacheles #' articles: 589

# %% [markdown]
# Recurring podcast announcement pages surfaced in the exploratory BERTopic run. The inspection below documents those documents before they are excluded from the final modeling corpus.

# %%
# Inspect and remove the recurring Anti-Spiegel podcast announcement pages that surfaced in the exploratory BERTopic run.
as_podcast_announcement_mask = (
    df_clean["Text"].fillna("").str.contains(r"Anti-Spiegel-Podcast", case=False, regex=True)
    | df_clean["Text"].fillna("").str.contains(r"Den Podcast k[oö]nnen Sie hier", case=False, regex=True)
    | (
        df_clean["Text"].fillna("").str.contains(r"spotify", case=False, regex=True)
        & df_clean["Text"].fillna("").str.contains(r"\bVK\b|Netzwerk VK|russischen VK", case=False, regex=True)
    )
)

antispiegel_podcast_announcement_docs = df_clean.loc[
    as_podcast_announcement_mask,
    ["Date", "Title", "URL", "Text"],
].copy()
antispiegel_podcast_announcement_docs["removal_reason"] = "podcast_spotify_vk_announcement"
antispiegel_podcast_announcement_docs["TextExcerpt"] = (
    antispiegel_podcast_announcement_docs["Text"].fillna("").str.slice(0, 400)
)

print(f"Podcast announcement pages identified for exclusion: {len(antispiegel_podcast_announcement_docs):,}")
display(
    antispiegel_podcast_announcement_docs[["Date", "Title", "URL", "TextExcerpt", "removal_reason"]]
)

df_clean = df_clean.loc[~as_podcast_announcement_mask].copy()
print(f"Rows after removing podcast announcement pages: {len(df_clean):,}")
# Out:
# Podcast announcement pages identified for exclusion: 24
#           Date                                              Title  \
# 276 2025-08-02                       Eine geopolitische Weltreise
# 289 2025-08-08                     Nächste Woche wird es spannend
# 327 2025-08-23                  Die 7 Zwerge aus Europa bei Trump
# 348 2025-08-29     Deutschland geht für die Ukraine vor die Hunde
# 395 2025-09-08  Warum gelingt es in Russland, dass Christen un...
# 423 2025-09-15  Drohnen über Polen und Reaktionen auf Kommenta...
# 452 2025-09-22    Gibt es in Russland eigentlich eine Opposition?
# 476 2025-09-29  Manipulierte Wahlen in Moldawien und Antworten...
# 500 2025-10-06         Wie ist das Gesundheitssystem in Russland?
# 522 2025-10-13  Trump ohne Friedensnobelpreis und das Bildungs...
# 550 2025-10-20  Selenskys erfolglose Reise zu Trump und die Fr...
# 580 2025-10-27  Skandal-Urteil zu Nord-Stream in Polen und Ant...
# 613 2025-11-03  Neue russische Waffen und die Wirkung der Sank...
# 635 2025-11-10   Stahlkrise in Deutschland, Reiseboom in Russland
# 647 2025-11-17  BRICS-Konferenz in Russland, AfD und ein Blick...
# 668 2025-11-24  Welche Chancen hat Trumps Friedensplan für die...
# 685 2025-12-01  Wie Kiew von dem Korruptionsskandal ablenken will
# 721 2025-12-08  Wie Korruption im Westen als politisches Druck...
# 749 2025-12-15                   Klaut die EU das russische Geld?
# 772 2025-12-22    Aufstand in der EU gegen Merz und von der Leyen
# 786 2025-12-29  Der feine Unterschied zwischen guten Sanktione...
# 812 2026-01-12  Bedeuten Trumps Ambitionen auf Grönland das En...
# 846 2026-01-19                       Schlechte Zeiten für die EU…
# 866 2026-01-26  Nach Davos herrscht in der EU Ratlosigkeit, we...
#
#                                                    URL  \
# 276  https://anti-spiegel.ru/2025/eine-geopolitisch...
# 289  https://anti-spiegel.ru/2025/naechste-woche-wi...
# 327  https://anti-spiegel.ru/2025/die-7-zwerge-aus-...
# 348  https://anti-spiegel.ru/2025/deutschland-geht-...
# 395  https://anti-spiegel.ru/2025/warum-gelingt-es-...
# 423  https://anti-spiegel.ru/2025/drohnen-ueber-pol...
# 452  https://anti-spiegel.ru/2025/gibt-es-in-russla...
# 476  https://anti-spiegel.ru/2025/manipulierte-wahl...
# 500  https://anti-spiegel.ru/2025/wie-ist-das-gesun...
# 522  https://anti-spiegel.ru/2025/trump-ohne-friede...
# 550  https://anti-spiegel.ru/2025/selenskys-erfolgl...
# 580  https://anti-spiegel.ru/2025/skandal-urteil-zu...
# 613  https://anti-spiegel.ru/2025/neue-russische-wa...
# 635  https://anti-spiegel.ru/2025/stahlkrise-in-deu...
# 647  https://anti-spiegel.ru/2025/brics-konferenz-i...
# 668  https://anti-spiegel.ru/2025/welche-chancen-ha...
# 685  https://anti-spiegel.ru/2025/wie-kiew-von-dem-...
# 721  https://anti-spiegel.ru/2025/wie-korruption-im...
# 749  https://anti-spiegel.ru/2025/klaut-die-eu-das-...
# 772  https://anti-spiegel.ru/2025/aufstand-in-der-e...
# 786  https://anti-spiegel.ru/2025/der-feine-untersc...
# 812  https://anti-spiegel.ru/2026/bedeuten-trumps-a...
# 846  https://anti-spiegel.ru/2026/schlechte-zeiten-...
# 866  https://anti-spiegel.ru/2026/nach-davos-herrsc...
#
#                                            TextExcerpt  \
# 276  Dieses Mal haben wir beim Anti-Spiegel-Podcast...
# 289  Das beherrschende Thema dieses Anti-Spiegel-Po...
# 327  Natürlich war das Treffen von Trump mit Selens...
# 348  Diese Mal hatten wir beim Anti-Spiegel-Podcast...
# 395  Nachdem Tacheles wöchentlich erscheint, haben ...
# 423  Da der Anti-Spiegel-Podcast nun aus zwei Theme...
# 452  Im politischen Teil des Podcasts ging es diese...
# 476  Diese Woche ist der Anti-Spiegel-Podcast ein M...
# 500  Diese Folge des Anti-Spiegel-Podcasts beginnen...
# 522  Wie immer ging es im ersten Teil des Anti-Spie...
# 550  Im ersten Teil des Podcasts ging es natürlich ...
# 580  Der Anti-Spiegel-Podcast ist eine Mischung aus...
# 613  Auch diese Woche besteht der Anti-Spiegel wied...
# 635  Wie immer besteht der Anti-Spiegel-Podcast aus...
# 647  Da Thomas Röper zur BRICS-Konferenz im russisc...
# 668  In dieser Ausgabe des Anti-Spiegel-Podcasts ge...
# 685  In diesem Anti-Spiegel-Podcast haben wir noch ...
# 721  Im politischen Teil des Anti-Spiegel-Podcast g...
# 749  Das wohl wichtigste Thema dieser Tage, die Fra...
# 772  Letzte Woche was es so, als habe die Welt den ...
# 786  Die letzten Tage waren unterhaltsam, denn eine...
# 812  Die ersten Tage des neuen Jahres haben große g...
# 846  Die letzte Woche war voll von noch vor kurzem ...
# 866  Natürlich war die verrückte Woche in Davos und...
#
#                       removal_reason
# 276  podcast_spotify_vk_announcement
# 289  podcast_spotify_vk_announcement
# 327  podcast_spotify_vk_announcement
# 348  podcast_spotify_vk_announcement
# 395  podcast_spotify_vk_announcement
# 423  podcast_spotify_vk_announcement
# 452  podcast_spotify_vk_announcement
# 476  podcast_spotify_vk_announcement
# 500  podcast_spotify_vk_announcement
# 522  podcast_spotify_vk_announcement
# 550  podcast_spotify_vk_announcement
# 580  podcast_spotify_vk_announcement
# 613  podcast_spotify_vk_announcement
# 635  podcast_spotify_vk_announcement
# 647  podcast_spotify_vk_announcement
# 668  podcast_spotify_vk_announcement
# 685  podcast_spotify_vk_announcement
# 721  podcast_spotify_vk_announcement
# 749  podcast_spotify_vk_announcement
# 772  podcast_spotify_vk_announcement
# 786  podcast_spotify_vk_announcement
# 812  podcast_spotify_vk_announcement
# 846  podcast_spotify_vk_announcement
# 866  podcast_spotify_vk_announcement
# Rows after removing podcast announcement pages: 565

# %%
antispiegel_clean = df_clean.copy()
antispiegel_clean = antispiegel_clean[['Date', 'Title', 'Text', 'source']].copy()
antispiegel_clean.to_csv("antispiegel_clean.csv", index=False, encoding="utf-8")

# %% [markdown]
# ## EDA

# %%
# Create a table showing number of articles per month
df_clean['Date'] = pd.to_datetime(df_clean['Date'])
articles_per_month = df_clean.groupby(df_clean['Date'].dt.to_period('M')).size().reset_index(name='article_count')
articles_per_month.columns = ['month', 'article_count']
articles_per_month
# Out:
#      month  article_count
# 0  2025-08             86
# 1  2025-09            114
# 2  2025-10            104
# 3  2025-11             77
# 4  2025-12            105
# 5  2026-01             79

# %%
import matplotlib.pyplot as plt

# Create a time series plot of articles per month
fig, ax = plt.subplots(figsize=(10, 6))

# Convert period to timestamp for plotting
articles_per_month['month_ts'] = articles_per_month['month'].dt.to_timestamp()

ax.plot(articles_per_month['month_ts'], articles_per_month['article_count'], marker='o', linewidth=2, markersize=8)

ax.set_xlabel('Month', fontsize=12)
ax.set_ylabel('Number of Articles', fontsize=12)
ax.set_title('Antispiegel Articles Over Time (Aug 2025 - Jan 2026)', fontsize=14)

plt.xticks(rotation=45)
ax.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

sns.set_theme(style="whitegrid", context="talk")
plt.rcParams["figure.figsize"] = (12, 6)

eda_df = df_clean.copy()
eda_df["Date"] = pd.to_datetime(eda_df["Date"], errors="coerce")

eda_df["Text"] = eda_df["Text"].astype("string")
eda_df = eda_df.dropna(subset=["Date", "Text"]).copy()

print(f"Rows used for EDA: {len(eda_df):,}")
# Out:
# Rows used for EDA: 565

# %%
eda_df["article_length_words"] = eda_df["Text"].str.split().str.len()
eda_df["article_length_chars"] = eda_df["Text"].str.len()

eda_df["article_length_words"].describe(
    percentiles=[0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]
).round(1)
# Out:
# count     565.0
# mean     1445.8
# std       793.0
# min        62.0
# 10%       555.8
# 25%       948.0
# 50%      1363.0
# 75%      1838.0
# 90%      2286.0
# 95%      2867.4
# 99%      3975.2
# max      6766.0
# Name: article_length_words, dtype: float64

# %%
q99 = eda_df["article_length_words"].quantile(0.99)
length_plot = eda_df[eda_df["article_length_words"] <= q99]

fig, ax = plt.subplots(figsize=(12, 6))
sns.histplot(
    length_plot["article_length_words"],
    bins=50,
    kde=True,
    color="#1f77b4",
    edgecolor="white",
    alpha=0.9,
    ax=ax,
)

ax.axvline(eda_df["article_length_words"].median(), color="#d62728", linestyle="--", linewidth=2, label="Median")
ax.axvline(eda_df["article_length_words"].mean(), color="#2ca02c", linestyle="-.", linewidth=2, label="Mean")
ax.set_title("Nius Article Length Distribution (Words)")
ax.set_xlabel("Words per article (up to 99th percentile)")
ax.set_ylabel("Number of articles")
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Filter articles with low word count (first bar in histogram, approximately 0-100 words)
low_word_articles = eda_df[eda_df["article_length_words"] <= 200]

print(f"Number of articles with <= 100 words: {len(low_word_articles)}")
low_word_articles[["Date", "Title", "Text", "article_length_words"]].sort_values("article_length_words")
# Out:
# Number of articles with <= 100 words: 11
#           Date                                              Title  \
# 649 2025-11-17  Interview mit dem sächsischen AfD-Chef Jörg Urban
# 462 2025-09-25  Interview mit den Anwälten von Thomas Röper un...
# 509 2025-10-11        Ein weiteres Interview über mein neues Buch
# 297 2025-08-10  Warum eine Mutter und deutsche Abgeordnete nac...
# 446 2025-09-21  Das erste Interview über mein neues Buch zur F...
# 671 2025-11-26     Zwei Tage Geburtstagpause auf dem Anti-Spiegel
# 321 2025-08-22  Meine Anwälte erklären, wie wir uns gegen die ...
# 334 2025-08-26  Die Bank hat das Spendenkonto für den Rechtsst...
# 543 2025-10-19  Der Bericht eines OSZE-Wahlbeobachters über di...
# 664 2025-11-22  Selensky spricht von der „sehr schwierigen Ent...
# 805 2026-01-12  Wie die Bundesregierung die Presse- und Meinun...
#
#                                                   Text  article_length_words
# 649  Der Fraktionsvorsitzenden der AfD im sächsisch...                    62
# 462  Markus Fiedler hat für apolut ein Interview mi...                    79
# 509  Da ich aufgrund der politischen Verfolgung in ...                    93
# 297  Dieses Interview finde ich aus sehr vielen Grü...                   102
# 446  Vor einigen Wochen ist mein neues Buch darüber...                   102
# 671  Ich habe schon geschrieben, dass es auf dem An...                   133
# 321  Da NuoViso diese Woche sein Sommerfest feiert ...                   153
# 334  Die Anwälte argumentieren, dass die Möglichkei...                   154
# 543  Über die Parlamentswahlen, die vor drei Wochen...                   158
# 664  Der ukrainische Machthaber Selensky hat sich a...                   165
# 805  Die Bundesregierung will im Zuge der Umsetzung...                   192

# %% [markdown]
# Even with a peak of articles containing a low number of words, it was decided to leave those short articles in as after manual check they seem to meaningfully contribute to the overall dataset in terms of discussed topics etc.

# %% [markdown]
# ## BERTopic

# %%
from pathlib import Path
import sys

def resolve_project_root() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in (cwd, *cwd.parents):
        if (candidate / "1a_BERTopic").exists():
            return candidate
    raise FileNotFoundError("Could not locate project root containing 1a_BERTopic")

project_root = resolve_project_root()
module_root = project_root / "1a_BERTopic"

if str(module_root) not in sys.path:
    sys.path.insert(0, str(module_root))

# %%
from bertopic_pipeline import run_bertopic_pipeline

# %%
from bertopic_config import BERTopicConfig, title_config

# %%
from pathlib import Path
import sys

def resolve_project_root() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in (cwd, *cwd.parents):
        if (candidate / "1a_BERTopic").exists():
            return candidate
    raise FileNotFoundError("Could not locate project root containing 1a_BERTopic")

PROJECT_ROOT = resolve_project_root()
MODULE_ROOT = PROJECT_ROOT / "1a_BERTopic"
if str(MODULE_ROOT) not in sys.path:
    sys.path.insert(0, str(MODULE_ROOT))

print("cwd:", Path.cwd())
print("project root added:", PROJECT_ROOT)
print("bertopic module root added:", MODULE_ROOT)
# Out:
# cwd: /Users/MattisHaumann/Dev/Thesis/00_Initial EDA
# project root added: /Users/MattisHaumann/Dev/Thesis
# bertopic module root added: /Users/MattisHaumann/Dev/Thesis/1a_BERTopic

# %%
# 1) BERTopic on full article text
result_full_text = run_bertopic_pipeline(
    df=df_clean,
    text_col="Text",
    config=BERTopicConfig(),
    id_col="URL",
    source_name="Antispiegel",
)

# Keep downstream notebook cells unchanged (they use `result`)
result_as = result_full_text
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-19 16:12:10,436 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 2026-03-19 16:12:16,529 - BERTopic - Embedding - Completed ✓
# 2026-03-19 16:12:16,530 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-03-19 16:12:17,611 - BERTopic - Dimensionality - Completed ✓
# 2026-03-19 16:12:17,617 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-03-19 16:12:17,633 - BERTopic - Cluster - Completed ✓
# 2026-03-19 16:12:17,635 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-03-19 16:12:18,144 - BERTopic - Representation - Completed ✓

# %%
topic_info = result_as["topic_info"]
topic_info.head(20)
# Out:
#    Topic  Count                                        Name  \
# 0     -1     13         -1_mittelmeer_kirks_robinson_zypern
# 1      0    507           0_selensky_ukrainischen_kiew_merz
# 2      1     24  1_moldawien_sandu_moldawischen_moldawische
# 3      2     21  2_gaza_netanjahu_israelischen_gazastreifen
#
#                                       Representation  \
# 0  [mittelmeer, kirks, robinson, zypern, the, mei...
# 1  [selensky, ukrainischen, kiew, merz, moskau, e...
# 2  [moldawien, sandu, moldawischen, moldawische, ...
# 3  [gaza, netanjahu, israelischen, gazastreifen, ...
#
#                                  Representative_Docs
# 0  [The Grayzone hat schon am 12. September einen...
# 1  [Letzte Woche war es, als würde die ganze Welt...
# 2  [Die pro-westliche Regierung in Moldawien hat ...
# 3  [Israel hat eine international scharf kritisie...

# %%
# 1) BERTopic on full article text
result_full_text = run_bertopic_pipeline(
    df=df_clean,
    text_col="Text",
    config=BERTopicConfig(
        hdbscan_min_cluster_size=8,   # default 20 -> smaller topics possible
        hdbscan_min_samples=2,        # default 10 -> fewer docs pushed to -1
        min_df=1,                     # keep rarer terms in small corpus
        max_df=0.95,                  # avoid over-pruning frequent terms
        umap_n_neighbors=10,          # more local structure
        umap_min_dist=0.05,           # slight separation between clusters
        nr_topics=None,               # do not force topic reduction
    ),
    id_col="URL",
    source_name="Antispiegel",
)


# Keep downstream notebook cells unchanged (they use `result`)
result_as = result_full_text
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-19 16:12:22,968 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 2026-03-19 16:12:25,828 - BERTopic - Embedding - Completed ✓
# 2026-03-19 16:12:25,829 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-03-19 16:12:26,379 - BERTopic - Dimensionality - Completed ✓
# 2026-03-19 16:12:26,379 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-03-19 16:12:26,392 - BERTopic - Cluster - Completed ✓
# 2026-03-19 16:12:26,395 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-03-19 16:12:27,586 - BERTopic - Representation - Completed ✓

# %%
topic_info = result_as["topic_info"]
topic_info.head(20)
# Out:
#     Topic  Count                                         Name  \
# 0      -1     73                 -1_spiegel_kirk_nato_charlie
# 1       0     47     0_trumps_demokraten_venezuela_washington
# 2       1     41       1_selensky_nabu_ukrainischen_selenskys
# 3       2     32     2_vermögenswerte_belgien_euro_kommission
# 4       3     28             3_merz_macron_deutsche_koalition
# 5       4     24        4_raketen_burevestnik_poseidon_rakete
# 6       5     24             5_selensky_europäer_plan_treffen
# 7       6     23      6_polen_ukrainer_ukrainischen_polnische
# 8       7     22          7_fernen_treffen_fernen osten_osten
# 9       8     21                8_gaza_israel_hamas_netanjahu
# 10      9     19         9_eu kommission_kommission_nato_baud
# 11     10     17            10_spiegel_cia_hebel_reitschuster
# 12     11     16               11_nato_ndr_rostock_österreich
# 13     12     15     12_spiegel_bellingcat_journalisten_occrp
# 14     13     13        13_wahlen_moldawien_wahl_moldawischen
# 15     14     12    14_iran_georgien_georgische_aserbaidschan
# 16     15     11                 15_nato_europäer_trumps_plan
# 17     16     11              16_merkel_minsker_abkommen_2021
# 18     17     10  17_indien_china_trumps_sicherheitsstrategie
# 19     18     10             18_ungarn_kiew_angriffe_druschba
#
#                                        Representation  \
# 0   [spiegel, kirk, nato, charlie, türkei, bip, br...
# 1   [trumps, demokraten, venezuela, washington, tr...
# 2   [selensky, nabu, ukrainischen, selenskys, korr...
# 3   [vermögenswerte, belgien, euro, kommission, ge...
# 4   [merz, macron, deutsche, koalition, euro, verm...
# 5   [raketen, burevestnik, poseidon, rakete, reich...
# 6   [selensky, europäer, plan, treffen, trumps, si...
# 7   [polen, ukrainer, ukrainischen, polnische, pol...
# 8   [fernen, treffen, fernen osten, osten, möchte,...
# 9   [gaza, israel, hamas, netanjahu, israelische, ...
# 10  [eu kommission, kommission, nato, baud, gesetz...
# 11  [spiegel, cia, hebel, reitschuster, frau hebel...
# 12  [nato, ndr, rostock, österreich, beitritt, bru...
# 13  [spiegel, bellingcat, journalisten, occrp, rei...
# 14  [wahlen, moldawien, wahl, moldawischen, sandu,...
# 15  [iran, georgien, georgische, aserbaidschan, ge...
# 16  [nato, europäer, trumps, plan, punkt, friedens...
# 17  [merkel, minsker, abkommen, 2021, minsker abko...
# 18  [indien, china, trumps, sicherheitsstrategie, ...
# 19  [ungarn, kiew, angriffe, druschba, pipeline, u...
#
#                                   Representative_Docs
# 0   [Der Spiegel sieht sich als Verteidiger all de...
# 1   [Die politische Woche in den USA war ausgespro...
# 2   [Der Korruptionsskandal in der Ukraine wird vo...
# 3   [Vor dem gestrigen EU-Gipfel habe ich berichte...
# 4   [Und wieder war der Bericht des Deutschland-Ko...
# 5   [In den 80er Jahren sorgte der NATO-Doppelbesc...
# 6   [Axios hat am Mittwoch gemeldet, die US-Regier...
# 7   [Aus aktuellem Anlass veröffentliche ich hier ...
# 8   [Die Ergebnisse des fünfstündigen Gespräche zw...
# 9   [Natürlich war der Angriff der Hamas auf Israe...
# 10  [Der belgische Verteidigungsminister Francken ...
# 11  [Der wöchentliche Nachrichtenrückblick des rus...
# 12  [In Russland sind die Diskussionen in Österrei...
# 13  [Eine Methode westlicher Medien wie dem Spiege...
# 14  [Über die Ende September anstehenden Parlament...
# 15  [Seit einigen Monaten berichte ich verstärkt ü...
# 16  [Wie jede Woche war der Bericht des Deutschlan...
# 17  [Letzte Woche war es, als würde die ganze Welt...
# 18  [Ich habe gestern bereits berichtet, dass Trum...
# 19  [Ich berichte seit über einer Woche über den B...

# %% [markdown]
# ### Outlier Reduction (focused section)
#
# This section starts from the already fitted Antispiegel topic model (`result_as`) and keeps the reduction workflow compact.
#
# The recurring Anti-Spiegel podcast announcement pages identified in the exploratory run are filtered in the cleaning section before BERTopic fitting, so the reduced model below already uses the refiltered corpus.
#
# > **Final workflow to use downstream:** `strategy="c-tf-idf"` with `threshold=0.10`.

# %%
import pandas as pd
from copy import deepcopy

# Keep aligned with the exact reduced-model baseline selected above (result_as).
base_result = result_as
topic_model_base = base_result["topic_model"]
docs_as = list(base_result["docs"])
topics_as = list(base_result["topics"])
prepared_docs = base_result["prepared_documents"].copy()
baseline_topic_ids = {topic for topic in topics_as if topic != -1}

new_topics_ctfidf_threshold = topic_model_base.reduce_outliers(
    docs_as,
    topics_as,
    strategy="c-tf-idf",
    threshold=0.10,
)
new_topics_ctfidf_threshold = list(new_topics_ctfidf_threshold)

redistributed_topic_ids = {topic for topic in new_topics_ctfidf_threshold if topic != -1}
unexpected_topic_ids = sorted(redistributed_topic_ids - baseline_topic_ids)
if unexpected_topic_ids:
    raise ValueError(
        f"Outlier reduction introduced new topic ids: {unexpected_topic_ids}. "
        "This notebook should only redistribute -1 documents into existing topics."
    )

topic_model_ctfidf_threshold = deepcopy(topic_model_base)
vectorizer_same = deepcopy(topic_model_base.vectorizer_model)
ctfidf_same = deepcopy(topic_model_base.ctfidf_model)
representation_same = deepcopy(topic_model_base.representation_model)

topic_model_ctfidf_threshold.update_topics(
    docs_as,
    topics=new_topics_ctfidf_threshold,
    vectorizer_model=vectorizer_same,
    ctfidf_model=ctfidf_same,
    representation_model=representation_same,
    top_n_words=topic_model_base.top_n_words,
)
topic_model_ctfidf_threshold.topics_ = list(new_topics_ctfidf_threshold)

topic_info_ctfidf_threshold = topic_model_ctfidf_threshold.get_topic_info().copy()
topic_info_ctfidf_threshold["OriginalTopic"] = topic_info_ctfidf_threshold["Topic"]
topic_info_ctfidf_threshold["TopicNameClean"] = topic_info_ctfidf_threshold["Name"].str.replace(r"^\d+_", "", regex=True)

ranked_topics = (
    topic_info_ctfidf_threshold.loc[topic_info_ctfidf_threshold["Topic"] != -1, ["Topic", "Count"]]
    .sort_values(["Count", "Topic"], ascending=[False, True])
    .reset_index(drop=True)
)
ranked_topics["DisplayTopic"] = range(1, len(ranked_topics) + 1)
display_topic_map = dict(zip(ranked_topics["Topic"], ranked_topics["DisplayTopic"]))

topic_info_ctfidf_threshold["DisplayTopic"] = (
    topic_info_ctfidf_threshold["Topic"].map(display_topic_map).astype("Int64")
)
topic_info_ctfidf_threshold["DisplayLabel"] = topic_info_ctfidf_threshold.apply(
    lambda row: "Outliers"
    if row["Topic"] == -1
    else f"Topic {int(row['DisplayTopic'])} — {row['TopicNameClean']}",
    axis=1,
)

ordered_cols = ["OriginalTopic", "DisplayTopic", "DisplayLabel", "TopicNameClean"]
remaining_cols = [col for col in topic_info_ctfidf_threshold.columns if col not in ordered_cols]
topic_info_ctfidf_threshold = topic_info_ctfidf_threshold[ordered_cols + remaining_cols]

topic_name_map_reduced = dict(zip(topic_info_ctfidf_threshold["Topic"], topic_info_ctfidf_threshold["Name"]))
display_label_map = dict(zip(topic_info_ctfidf_threshold["Topic"], topic_info_ctfidf_threshold["DisplayLabel"]))

doc_info_reduced = base_result["doc_info"].copy()
doc_info_reduced["Topic"] = list(new_topics_ctfidf_threshold)
if "Name" in doc_info_reduced.columns:
    doc_info_reduced["Name"] = doc_info_reduced["Topic"].map(topic_name_map_reduced)
doc_info_reduced["DisplayTopic"] = doc_info_reduced["Topic"].map(display_topic_map).astype("Int64")
doc_info_reduced["DisplayLabel"] = doc_info_reduced["Topic"].map(display_label_map)

result_as_reduced = dict(base_result)
result_as_reduced["topics"] = list(new_topics_ctfidf_threshold)
result_as_reduced["topic_model"] = topic_model_ctfidf_threshold
result_as_reduced["topic_info"] = topic_info_ctfidf_threshold
result_as_reduced["topic_info_display"] = topic_info_ctfidf_threshold.copy()
result_as_reduced["doc_info"] = doc_info_reduced
result_as_reduced["display_topic_map"] = display_topic_map
result_as_reduced["display_label_map"] = display_label_map

summary_final = pd.DataFrame([
    {
        "Variant": "baseline",
        "Outlier_Count": int((pd.Series(topics_as) == -1).sum()),
        "Non_Outlier_Topic_Count": len(baseline_topic_ids),
    },
    {
        "Variant": "ctfidf_threshold_0.10",
        "Outlier_Count": int((pd.Series(new_topics_ctfidf_threshold) == -1).sum()),
        "Non_Outlier_Topic_Count": len(redistributed_topic_ids),
    },
])
display(summary_final)
display(topic_info_ctfidf_threshold.head(20))
# Out:
# 2026-03-19 16:12:29,322 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#                  Variant  Outlier_Count  Non_Outlier_Topic_Count
# 0               baseline             73                       30
# 1  ctfidf_threshold_0.10             37                       30
#     OriginalTopic  DisplayTopic  \
# 0              -1          <NA>
# 1               0             1
# 2               1             2
# 3               2             3
# 4               3             4
# 5               4             6
# 6               5             7
# 7               6             5
# 8               7             9
# 9               8             8
# 10              9            11
# 11             10            12
# 12             11            13
# 13             12            10
# 14             13            15
# 15             14            14
# 16             15            16
# 17             16            17
# 18             17            18
# 19             18            19
#
#                                          DisplayLabel  \
# 0                                            Outliers
# 1   Topic 1 — trumps_demokraten_venezuela_amerikan...
# 2      Topic 2 — selensky_nabu_ukrainischen_selenskys
# 3    Topic 3 — vermögenswerte_belgien_euro_kommission
# 4                 Topic 4 — deutsche_merz_macron_euro
# 5       Topic 6 — raketen_burevestnik_poseidon_rakete
# 6            Topic 7 — selensky_europäer_treffen_plan
# 7     Topic 5 — polen_ukrainischen_ukrainer_polnische
# 8         Topic 9 — fernen_treffen_fernen osten_osten
# 9               Topic 8 — israel_gaza_netanjahu_hamas
# 10      Topic 11 — eu kommission_kommission_nato_baud
# 11          Topic 12 — spiegel_cia_hebel_reitschuster
# 12         Topic 13 — nato_österreich_neutralität_ndr
# 13   Topic 10 — spiegel_bellingcat_journalisten_occrp
# 14      Topic 15 — wahlen_moldawien_wahl_moldawischen
# 15  Topic 14 — iran_aserbaidschan_georgien_georgische
# 16               Topic 16 — nato_europäer_trumps_plan
# 17            Topic 17 — merkel_minsker_abkommen_2021
# 18  Topic 18 — indien_china_trumps_sicherheitsstra...
# 19           Topic 19 — ungarn_kiew_angriffe_druschba
#
#                                 TopicNameClean  Topic  Count  \
# 0           -1_thailand_akw_britischen_spiegel     -1     37
# 1   trumps_demokraten_venezuela_amerikanischen      0     54
# 2         selensky_nabu_ukrainischen_selenskys      1     43
# 3       vermögenswerte_belgien_euro_kommission      2     35
# 4                    deutsche_merz_macron_euro      3     31
# 5          raketen_burevestnik_poseidon_rakete      4     26
# 6               selensky_europäer_treffen_plan      5     26
# 7        polen_ukrainischen_ukrainer_polnische      6     27
# 8            fernen_treffen_fernen osten_osten      7     22
# 9                  israel_gaza_netanjahu_hamas      8     23
# 10          eu kommission_kommission_nato_baud      9     19
# 11              spiegel_cia_hebel_reitschuster     10     17
# 12             nato_österreich_neutralität_ndr     11     17
# 13       spiegel_bellingcat_journalisten_occrp     12     21
# 14          wahlen_moldawien_wahl_moldawischen     13     13
# 15      iran_aserbaidschan_georgien_georgische     14     14
# 16                   nato_europäer_trumps_plan     15     11
# 17                merkel_minsker_abkommen_2021     16     11
# 18    indien_china_trumps_sicherheitsstrategie     17     10
# 19               ungarn_kiew_angriffe_druschba     18     10
#
#                                             Name  \
# 0             -1_thailand_akw_britischen_spiegel
# 1   0_trumps_demokraten_venezuela_amerikanischen
# 2         1_selensky_nabu_ukrainischen_selenskys
# 3       2_vermögenswerte_belgien_euro_kommission
# 4                    3_deutsche_merz_macron_euro
# 5          4_raketen_burevestnik_poseidon_rakete
# 6               5_selensky_europäer_treffen_plan
# 7        6_polen_ukrainischen_ukrainer_polnische
# 8            7_fernen_treffen_fernen osten_osten
# 9                  8_israel_gaza_netanjahu_hamas
# 10          9_eu kommission_kommission_nato_baud
# 11             10_spiegel_cia_hebel_reitschuster
# 12            11_nato_österreich_neutralität_ndr
# 13      12_spiegel_bellingcat_journalisten_occrp
# 14         13_wahlen_moldawien_wahl_moldawischen
# 15     14_iran_aserbaidschan_georgien_georgische
# 16                  15_nato_europäer_trumps_plan
# 17               16_merkel_minsker_abkommen_2021
# 18   17_indien_china_trumps_sicherheitsstrategie
# 19              18_ungarn_kiew_angriffe_druschba
#
#                                        Representation  \
# 0   [thailand, akw, britischen, spiegel, nepal, tü...
# 1   [trumps, demokraten, venezuela, amerikanischen...
# 2   [selensky, nabu, ukrainischen, selenskys, korr...
# 3   [vermögenswerte, belgien, euro, kommission, ru...
# 4   [deutsche, merz, macron, euro, koalition, afd,...
# 5   [raketen, burevestnik, poseidon, rakete, reich...
# 6   [selensky, europäer, treffen, plan, trumps, si...
# 7   [polen, ukrainischen, ukrainer, polnische, nor...
# 8   [fernen, treffen, fernen osten, osten, möchte,...
# 9   [israel, gaza, netanjahu, hamas, israelische, ...
# 10  [eu kommission, kommission, nato, baud, gesetz...
# 11  [spiegel, cia, hebel, reitschuster, frau hebel...
# 12  [nato, österreich, neutralität, ndr, rostock, ...
# 13  [spiegel, bellingcat, journalisten, occrp, chi...
# 14  [wahlen, moldawien, wahl, moldawischen, sandu,...
# 15  [iran, aserbaidschan, georgien, georgische, ar...
# 16  [nato, europäer, trumps, plan, punkt, friedens...
# 17  [merkel, minsker, abkommen, 2021, minsker abko...
# 18  [indien, china, trumps, sicherheitsstrategie, ...
# 19  [ungarn, kiew, angriffe, druschba, pipeline, u...
#
#                                   Representative_Docs
# 0   [Der Spiegel sieht sich als Verteidiger all de...
# 1   [Die politische Woche in den USA war ausgespro...
# 2   [Der Korruptionsskandal in der Ukraine wird vo...
# 3   [Vor dem gestrigen EU-Gipfel habe ich berichte...
# 4   [Und wieder war der Bericht des Deutschland-Ko...
# 5   [In den 80er Jahren sorgte der NATO-Doppelbesc...
# 6   [Axios hat am Mittwoch gemeldet, die US-Regier...
# 7   [Aus aktuellem Anlass veröffentliche ich hier ...
# 8   [Die Ergebnisse des fünfstündigen Gespräche zw...
# 9   [Natürlich war der Angriff der Hamas auf Israe...
# 10  [Der belgische Verteidigungsminister Francken ...
# 11  [Der wöchentliche Nachrichtenrückblick des rus...
# 12  [In Russland sind die Diskussionen in Österrei...
# 13  [Eine Methode westlicher Medien wie dem Spiege...
# 14  [Über die Ende September anstehenden Parlament...
# 15  [Seit einigen Monaten berichte ich verstärkt ü...
# 16  [Wie jede Woche war der Bericht des Deutschlan...
# 17  [Letzte Woche war es, als würde die ganze Welt...
# 18  [Ich habe gestern bereits berichtet, dass Trum...
# 19  [Ich berichte seit über einer Woche über den B...

# %% [markdown]
# ### Save final reduced model (`as_model` overwrite)
#
# Persist the final threshold-based reduced model so this is the saved Antispiegel model variant for downstream loading.

# %%
from pathlib import Path
import shutil

# Keep a reusable reduced result dict in notebook memory and make it the current Antispiegel result.
result_as = result_as_reduced
result = result_as
topic_info = result_as["topic_info"]
def find_project_root(start: Path) -> Path:
    start = start.resolve()
    for candidate in (start, *start.parents):
        if (candidate / ".git").exists():
            return candidate
    raise FileNotFoundError("Could not find project root containing .git")

project_root = find_project_root(Path.cwd())
save_dir = project_root / "1a_BERTopic" / "local_outputs" / "as_model"
save_dir.parent.mkdir(parents=True, exist_ok=True)
if save_dir.exists():
    shutil.rmtree(save_dir)

topic_model_ctfidf_threshold.save(
    save_dir,
    serialization="safetensors",
    save_ctfidf=True,
    save_embedding_model="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2",
)

print(f"Saved final reduced model to: {save_dir}")
# Out:
# Saved final reduced model to: /Users/MattisHaumann/Dev/Thesis/1a_BERTopic/local_outputs/as_model

# %%
# Unified display numbering for the final reduced model (largest topic = Topic 1).
topic_display_result = result_as_reduced if "result_as_reduced" in globals() else result_as
topic_info = topic_display_result["topic_info"].copy()
display_topic_map = topic_display_result["display_topic_map"]
display_label_map = topic_display_result["display_label_map"]

display(topic_info.head(20))
# Out:
#     OriginalTopic  DisplayTopic  \
# 0              -1          <NA>
# 1               0             1
# 2               1             2
# 3               2             3
# 4               3             4
# 5               4             6
# 6               5             7
# 7               6             5
# 8               7             9
# 9               8             8
# 10              9            11
# 11             10            12
# 12             11            13
# 13             12            10
# 14             13            15
# 15             14            14
# 16             15            16
# 17             16            17
# 18             17            18
# 19             18            19
#
#                                          DisplayLabel  \
# 0                                            Outliers
# 1   Topic 1 — trumps_demokraten_venezuela_amerikan...
# 2      Topic 2 — selensky_nabu_ukrainischen_selenskys
# 3    Topic 3 — vermögenswerte_belgien_euro_kommission
# 4                 Topic 4 — deutsche_merz_macron_euro
# 5       Topic 6 — raketen_burevestnik_poseidon_rakete
# 6            Topic 7 — selensky_europäer_treffen_plan
# 7     Topic 5 — polen_ukrainischen_ukrainer_polnische
# 8         Topic 9 — fernen_treffen_fernen osten_osten
# 9               Topic 8 — israel_gaza_netanjahu_hamas
# 10      Topic 11 — eu kommission_kommission_nato_baud
# 11          Topic 12 — spiegel_cia_hebel_reitschuster
# 12         Topic 13 — nato_österreich_neutralität_ndr
# 13   Topic 10 — spiegel_bellingcat_journalisten_occrp
# 14      Topic 15 — wahlen_moldawien_wahl_moldawischen
# 15  Topic 14 — iran_aserbaidschan_georgien_georgische
# 16               Topic 16 — nato_europäer_trumps_plan
# 17            Topic 17 — merkel_minsker_abkommen_2021
# 18  Topic 18 — indien_china_trumps_sicherheitsstra...
# 19           Topic 19 — ungarn_kiew_angriffe_druschba
#
#                                 TopicNameClean  Topic  Count  \
# 0           -1_thailand_akw_britischen_spiegel     -1     37
# 1   trumps_demokraten_venezuela_amerikanischen      0     54
# 2         selensky_nabu_ukrainischen_selenskys      1     43
# 3       vermögenswerte_belgien_euro_kommission      2     35
# 4                    deutsche_merz_macron_euro      3     31
# 5          raketen_burevestnik_poseidon_rakete      4     26
# 6               selensky_europäer_treffen_plan      5     26
# 7        polen_ukrainischen_ukrainer_polnische      6     27
# 8            fernen_treffen_fernen osten_osten      7     22
# 9                  israel_gaza_netanjahu_hamas      8     23
# 10          eu kommission_kommission_nato_baud      9     19
# 11              spiegel_cia_hebel_reitschuster     10     17
# 12             nato_österreich_neutralität_ndr     11     17
# 13       spiegel_bellingcat_journalisten_occrp     12     21
# 14          wahlen_moldawien_wahl_moldawischen     13     13
# 15      iran_aserbaidschan_georgien_georgische     14     14
# 16                   nato_europäer_trumps_plan     15     11
# 17                merkel_minsker_abkommen_2021     16     11
# 18    indien_china_trumps_sicherheitsstrategie     17     10
# 19               ungarn_kiew_angriffe_druschba     18     10
#
#                                             Name  \
# 0             -1_thailand_akw_britischen_spiegel
# 1   0_trumps_demokraten_venezuela_amerikanischen
# 2         1_selensky_nabu_ukrainischen_selenskys
# 3       2_vermögenswerte_belgien_euro_kommission
# 4                    3_deutsche_merz_macron_euro
# 5          4_raketen_burevestnik_poseidon_rakete
# 6               5_selensky_europäer_treffen_plan
# 7        6_polen_ukrainischen_ukrainer_polnische
# 8            7_fernen_treffen_fernen osten_osten
# 9                  8_israel_gaza_netanjahu_hamas
# 10          9_eu kommission_kommission_nato_baud
# 11             10_spiegel_cia_hebel_reitschuster
# 12            11_nato_österreich_neutralität_ndr
# 13      12_spiegel_bellingcat_journalisten_occrp
# 14         13_wahlen_moldawien_wahl_moldawischen
# 15     14_iran_aserbaidschan_georgien_georgische
# 16                  15_nato_europäer_trumps_plan
# 17               16_merkel_minsker_abkommen_2021
# 18   17_indien_china_trumps_sicherheitsstrategie
# 19              18_ungarn_kiew_angriffe_druschba
#
#                                        Representation  \
# 0   [thailand, akw, britischen, spiegel, nepal, tü...
# 1   [trumps, demokraten, venezuela, amerikanischen...
# 2   [selensky, nabu, ukrainischen, selenskys, korr...
# 3   [vermögenswerte, belgien, euro, kommission, ru...
# 4   [deutsche, merz, macron, euro, koalition, afd,...
# 5   [raketen, burevestnik, poseidon, rakete, reich...
# 6   [selensky, europäer, treffen, plan, trumps, si...
# 7   [polen, ukrainischen, ukrainer, polnische, nor...
# 8   [fernen, treffen, fernen osten, osten, möchte,...
# 9   [israel, gaza, netanjahu, hamas, israelische, ...
# 10  [eu kommission, kommission, nato, baud, gesetz...
# 11  [spiegel, cia, hebel, reitschuster, frau hebel...
# 12  [nato, österreich, neutralität, ndr, rostock, ...
# 13  [spiegel, bellingcat, journalisten, occrp, chi...
# 14  [wahlen, moldawien, wahl, moldawischen, sandu,...
# 15  [iran, aserbaidschan, georgien, georgische, ar...
# 16  [nato, europäer, trumps, plan, punkt, friedens...
# 17  [merkel, minsker, abkommen, 2021, minsker abko...
# 18  [indien, china, trumps, sicherheitsstrategie, ...
# 19  [ungarn, kiew, angriffe, druschba, pipeline, u...
#
#                                   Representative_Docs
# 0   [Der Spiegel sieht sich als Verteidiger all de...
# 1   [Die politische Woche in den USA war ausgespro...
# 2   [Der Korruptionsskandal in der Ukraine wird vo...
# 3   [Vor dem gestrigen EU-Gipfel habe ich berichte...
# 4   [Und wieder war der Bericht des Deutschland-Ko...
# 5   [In den 80er Jahren sorgte der NATO-Doppelbesc...
# 6   [Axios hat am Mittwoch gemeldet, die US-Regier...
# 7   [Aus aktuellem Anlass veröffentliche ich hier ...
# 8   [Die Ergebnisse des fünfstündigen Gespräche zw...
# 9   [Natürlich war der Angriff der Hamas auf Israe...
# 10  [Der belgische Verteidigungsminister Francken ...
# 11  [Der wöchentliche Nachrichtenrückblick des rus...
# 12  [In Russland sind die Diskussionen in Österrei...
# 13  [Eine Methode westlicher Medien wie dem Spiege...
# 14  [Über die Ende September anstehenden Parlament...
# 15  [Seit einigen Monaten berichte ich verstärkt ü...
# 16  [Wie jede Woche war der Bericht des Deutschlan...
# 17  [Letzte Woche war es, als würde die ganze Welt...
# 18  [Ich habe gestern bereits berichtet, dass Trum...
# 19  [Ich berichte seit über einer Woche über den B...

# %% [markdown]
# ### UMAP topic map (reduced model, no re-fit)
#
# Visualize the final reduced topics from the threshold workflow above.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from umap import UMAP

run_result = result_as_reduced if "result_as_reduced" in globals() else result_as
topic_model_plot = run_result["topic_model"]
docs_plot = list(run_result["docs"])
topics_plot = list(run_result["topics"])
topic_info_plot = run_result["topic_info"].copy()
display_label_map = run_result["display_label_map"]

embeddings = topic_model_plot._extract_embeddings(docs_plot, method="document")
umap_model = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric="cosine").fit(embeddings)
df_plot = pd.DataFrame(umap_model.embedding_, columns=["x", "y"])
df_plot["topic"] = topics_plot

top_n = 15
fontsize = 12

top_topic_ids = (
    topic_info_plot.loc[topic_info_plot["Topic"] != -1]
    .nsmallest(top_n, "DisplayTopic")["Topic"]
    .tolist()
)

to_plot = df_plot.copy()
to_plot.loc[~to_plot["topic"].isin(top_topic_ids), "topic"] = -1
outliers = to_plot.loc[to_plot["topic"] == -1]
non_outliers = to_plot.loc[to_plot["topic"] != -1]

cmap = matplotlib.colors.ListedColormap([
    "#FF5722", "#03A9F4", "#4CAF50", "#80CBC4", "#673AB7",
    "#795548", "#E91E63", "#212121", "#00BCD4", "#CDDC39",
    "#AED581", "#FFE082", "#BCAAA4", "#B39DDB", "#F48FB1",
])

fig, ax = plt.subplots(figsize=(15, 15))
ax.scatter(outliers["x"], outliers["y"], c="#E0E0E0", s=1, alpha=0.3)
ax.scatter(non_outliers["x"], non_outliers["y"], c=non_outliers["topic"], s=1, alpha=0.3, cmap=cmap)

centroids = non_outliers.groupby("topic", as_index=False)[["x", "y"]].mean()
for _, row in centroids.iterrows():
    topic = int(row["topic"])
    label = display_label_map.get(topic, f"Topic {topic}")
    ax.text(row["x"], row["y"] * 1.01, label, fontsize=fontsize, horizontalalignment="center")

ax.text(0.99, 0.01, f"BERTopic (reduced) - Top {top_n} topics",
        transform=ax.transAxes, horizontalalignment="right", color="black")
plt.xticks([], [])
plt.yticks([], [])
plt.show()

# %%
# Legacy scratch cell intentionally left blank.

# %%
import seaborn as sns

# Ensure plotting libs exist in current kernel.
import matplotlib.pyplot as plt

# Re-run this cell after outlier reduction to visualize the final reduced model with unified topic numbering.
run_result = result_as_reduced if "result_as_reduced" in globals() else result_as
topic_info_run = run_result["topic_info"].copy()

if "DisplayTopic" not in topic_info_run.columns:
    topic_info_run["OriginalTopic"] = topic_info_run["Topic"]
    topic_info_run["TopicNameClean"] = topic_info_run["Name"].str.replace(r"^\d+_", "", regex=True)
    ranked_topics = (
        topic_info_run.loc[topic_info_run["Topic"] != -1, ["Topic", "Count"]]
        .sort_values(["Count", "Topic"], ascending=[False, True])
        .reset_index(drop=True)
    )
    ranked_topics["DisplayTopic"] = range(1, len(ranked_topics) + 1)
    display_topic_map = dict(zip(ranked_topics["Topic"], ranked_topics["DisplayTopic"]))
    topic_info_run["DisplayTopic"] = topic_info_run["Topic"].map(display_topic_map).astype("Int64")
    topic_info_run["DisplayLabel"] = topic_info_run.apply(
        lambda row: "Outliers"
        if row["Topic"] == -1
        else f"Topic {int(row['DisplayTopic'])} — {row['TopicNameClean']}",
        axis=1,
    )

top15_topics = (
    topic_info_run.loc[topic_info_run["Topic"] != -1]
    .nsmallest(15, "DisplayTopic")
    .sort_values("DisplayTopic")
    .copy()
)

fig, ax = plt.subplots(figsize=(14, 8))
sns.barplot(
    data=top15_topics,
    x="Count",
    y="DisplayLabel",
    order=top15_topics["DisplayLabel"].tolist(),
    palette="Blues_r",
    ax=ax,
)

ax.set_title("Top 15 Topics by Document Count (Reduced Model)")
ax.set_xlabel("Document Count")
ax.set_ylabel("Topic")
plt.tight_layout()
plt.show()

# %%
# Fix: ensure `result` exists for downstream cells (and ignore the stray `im` typo above)
if "result" not in globals():
    if "result_as" in globals():
        result = result_as
    elif "result_full_text" in globals():
        result = result_full_text
    else:
        raise NameError("No BERTopic result found. Run the BERTopic pipeline cell first.")

topic_info = result["topic_info"]
print(f"`result` is ready. Topics: {len(topic_info)}")
topic_info.head(5)
# Out:
# `result` is ready. Topics: 31
#    OriginalTopic  DisplayTopic  \
# 0             -1          <NA>
# 1              0             1
# 2              1             2
# 3              2             3
# 4              3             4
#
#                                         DisplayLabel  \
# 0                                           Outliers
# 1  Topic 1 — trumps_demokraten_venezuela_amerikan...
# 2     Topic 2 — selensky_nabu_ukrainischen_selenskys
# 3   Topic 3 — vermögenswerte_belgien_euro_kommission
# 4                Topic 4 — deutsche_merz_macron_euro
#
#                                TopicNameClean  Topic  Count  \
# 0          -1_thailand_akw_britischen_spiegel     -1     37
# 1  trumps_demokraten_venezuela_amerikanischen      0     54
# 2        selensky_nabu_ukrainischen_selenskys      1     43
# 3      vermögenswerte_belgien_euro_kommission      2     35
# 4                   deutsche_merz_macron_euro      3     31
#
#                                            Name  \
# 0            -1_thailand_akw_britischen_spiegel
# 1  0_trumps_demokraten_venezuela_amerikanischen
# 2        1_selensky_nabu_ukrainischen_selenskys
# 3      2_vermögenswerte_belgien_euro_kommission
# 4                   3_deutsche_merz_macron_euro
#
#                                       Representation  \
# 0  [thailand, akw, britischen, spiegel, nepal, tü...
# 1  [trumps, demokraten, venezuela, amerikanischen...
# 2  [selensky, nabu, ukrainischen, selenskys, korr...
# 3  [vermögenswerte, belgien, euro, kommission, ru...
# 4  [deutsche, merz, macron, euro, koalition, afd,...
#
#                                  Representative_Docs
# 0  [Der Spiegel sieht sich als Verteidiger all de...
# 1  [Die politische Woche in den USA war ausgespro...
# 2  [Der Korruptionsskandal in der Ukraine wird vo...
# 3  [Vor dem gestrigen EU-Gipfel habe ich berichte...
# 4  [Und wieder war der Bericht des Deutschland-Ko...

# %% [markdown]
# ## OLD

# %%
# Full-text config for Antispiegel topic modeling
config_full_text = BERTopicConfig(
    min_text_chars=80,
    min_tokens=12,
    min_df=2,
    max_df=0.75,
    ngram_range=(1, 3),
    umap_n_neighbors=8,
    umap_n_components=5,
    umap_min_dist=0.0,
    hdbscan_min_cluster_size=4,
    hdbscan_min_samples=2,
    extra_stopwords=(
        "für", "hat", "haben", "wird", "werden", "wurde",
        "sagte", "sagt", "sei", "sind",
        "antispiegel", "artikel", "podcast", "video", "spotify",
    ),
)

# Title-only config for Antispiegel topic modeling
config_title = title_config(
    ngram_range=(1, 2),
    hdbscan_min_cluster_size=4,
    hdbscan_min_samples=2,
    extra_stopwords=(
        "für", "hat", "haben", "wird", "werden", "wurde",
        "sagte", "sagt", "sei", "sind",
        "antispiegel", "artikel", "podcast", "video", "spotify",
    ),
)

# %%
# 1) BERTopic on full article text
result_full_text = run_bertopic_pipeline(
    df=df_clean,
    text_col="Text",
    config=config_full_text,
    id_col="URL",
    source_name="Antispiegel",
)

# 2) BERTopic on titles only
result_title = run_bertopic_pipeline(
    df=df_clean,
    text_col="Title",
    config=config_title,
    id_col="URL",
    source_name="Antispiegel",
)

# Keep downstream notebook cells unchanged (they use `result`)
result = result_full_text
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-19 16:12:46,812 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 2026-03-19 16:12:50,059 - BERTopic - Embedding - Completed ✓
# 2026-03-19 16:12:50,059 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-03-19 16:12:50,705 - BERTopic - Dimensionality - Completed ✓
# 2026-03-19 16:12:50,706 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-03-19 16:12:50,715 - BERTopic - Cluster - Completed ✓
# 2026-03-19 16:12:50,716 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-03-19 16:12:51,763 - BERTopic - Representation - Completed ✓
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-19 16:12:57,080 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 2026-03-19 16:12:58,950 - BERTopic - Embedding - Completed ✓
# 2026-03-19 16:12:58,950 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-03-19 16:12:59,828 - BERTopic - Dimensionality - Completed ✓
# 2026-03-19 16:12:59,829 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-03-19 16:12:59,842 - BERTopic - Cluster - Completed ✓
# 2026-03-19 16:12:59,844 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-03-19 16:12:59,869 - BERTopic - Representation - Completed ✓

# %%
topic_info = result["topic_info"]
topic_info.head(20)
# Out:
#     Topic  Count                                              Name  \
# 0      -1     90            -1_vermögenswerte_indien_selensky_euro
# 1       0     27      0_selensky_sicherheitsgarantien_axios_dürfte
# 2       1     25              1_selensky_nabu_minditsch_korruption
# 3       2     16              2_moldawien_wahlen_wahl_moldawischen
# 4       3     15                     3_gaza_netanjahu_hamas_israel
# 5       4     13          4_aserbaidschan_iran_georgien_georgische
# 6       5     13                      5_ungarn_gps_druschba_steele
# 7       6     12                 6_polen_polnische_polnischen_nord
# 8       7     11                       7_drohnen_akw_polen_vorfall
# 9       8     11             8_nabu_selensky_timoschenko_selenskys
# 10      9     11                  9_merz_koalition_macron_willigen
# 11     10     10     10_feind_wladiwostok_kommission_eu kommission
# 12     11     10          11_china_chinesischen_taiwan_chinesische
# 13     12     10                   12_cia_reitschuster_modi_indien
# 14     13     10   13_strategie_europas_uno_staats regierungschefs
# 15     14     10           14_punkt_biden_friedensplan_trumps plan
# 16     15     10                 15_shutdown_demokraten_haus_weiße
# 17     16      9  16_macron_lecornu_premierminister_gewerkschaften
# 18     17      9          17_merz_bundeskanzler_sozialstaat_indien
# 19     18      9                          18_gas_lng_studie_winter
#
#                                        Representation  \
# 0   [vermögenswerte, indien, selensky, euro, china...
# 1   [selensky, sicherheitsgarantien, axios, dürfte...
# 2   [selensky, nabu, minditsch, korruption, selens...
# 3   [moldawien, wahlen, wahl, moldawischen, sandu,...
# 4   [gaza, netanjahu, hamas, israel, israelische, ...
# 5   [aserbaidschan, iran, georgien, georgische, ar...
# 6   [ungarn, gps, druschba, steele, angriffe, pipe...
# 7   [polen, polnische, polnischen, nord, nord stre...
# 8   [drohnen, akw, polen, vorfall, polnischen, nac...
# 9   [nabu, selensky, timoschenko, selenskys, jerma...
# 10  [merz, koalition, macron, willigen, koalition ...
# 11  [feind, wladiwostok, kommission, eu kommission...
# 12  [china, chinesischen, taiwan, chinesische, pek...
# 13  [cia, reitschuster, modi, indien, entwickelt, ...
# 14  [strategie, europas, uno, staats regierungsche...
# 15  [punkt, biden, friedensplan, trumps plan, akt,...
# 16  [shutdown, demokraten, haus, weiße, grönland, ...
# 17  [macron, lecornu, premierminister, gewerkschaf...
# 18  [merz, bundeskanzler, sozialstaat, indien, fri...
# 19  [gas, lng, studie, winter, 2021, pipelinegas, ...
#
#                                   Representative_Docs
# 0   [Letzte Woche war es, als würde die ganze Welt...
# 1   [Wahrscheinlich hat niemand von den Gesprächen...
# 2   [Der Korruptionsskandal in der Ukraine wird vo...
# 3   [Ich berichte in drei Artikeln über die Wahl i...
# 4   [Natürlich war der Angriff der Hamas auf Israe...
# 5   [Ich berichte viel über die Entwicklungen im S...
# 6   [Ich berichte seit über einer Woche über den B...
# 7   [Aus aktuellem Anlass veröffentliche ich hier ...
# 8   [Manche Dinge sind so offensichtlich, dass man...
# 9   [Im Sommer hat Selensky versucht, die von den ...
# 10  [Ich bin wirklich froh, dass die Sommerpause d...
# 11  [Westliche Politiker und Medien bestreiten veh...
# 12  [Das Telefonat zwischen dem amerikanischen und...
# 13  [Ich bin zufällig auf einen Artikel eines russ...
# 14  [Ich habe oft darauf hingewiesen, dass die Beh...
# 15  [Deutsche Medien freuen sich in ihren ersten B...
# 16  [Die letzte politische Woche in den USA war vo...
# 17  [Wie jeden Sonntag war der Korrespondentenberi...
# 18  [Ich habe bereits in einem Artikel erklärt, wi...
# 19  [Ich habe vor knapp einer Woche über die Fülls...

# %%
doc_info = result["doc_info"]
doc_info.head()
# Out:
#    original_index                                        document_id  \
# 0             269  https://anti-spiegel.ru/2025/bereitet-der-west...
# 1             270  https://anti-spiegel.ru/2025/eu-kommission-hat...
# 2             271  https://anti-spiegel.ru/2025/wahlkommission-re...
# 3             272  https://anti-spiegel.ru/2025/fordert-russland-...
# 4             273  https://anti-spiegel.ru/2025/der-spiegel-macht...
#
#    source_name                                           Document  Topic  \
# 0  Antispiegel  Der Streit um das Nationale Anti-Korruptionsbü...      8
# 1  Antispiegel  Die New York Times versucht seit langem vor Ge...     49
# 2  Antispiegel  Ende September stehen in Moldawien Parlamentsw...      2
# 3  Antispiegel  Ich bin auf die Geschichte zuerst bei RT-DE ge...     12
# 4  Antispiegel  Wer auch nicht-westliche Medien liest, der ist...     -1
#
#                                       Name  \
# 0    8_nabu_selensky_timoschenko_selenskys
# 1  49_merkel_minsker_2021_minsker abkommen
# 2     2_moldawien_wahlen_wahl_moldawischen
# 3          12_cia_reitschuster_modi_indien
# 4   -1_vermögenswerte_indien_selensky_euro
#
#                                       Representation  \
# 0  [nabu, selensky, timoschenko, selenskys, jerma...
# 1  [merkel, minsker, 2021, minsker abkommen, abko...
# 2  [moldawien, wahlen, wahl, moldawischen, sandu,...
# 3  [cia, reitschuster, modi, indien, entwickelt, ...
# 4  [vermögenswerte, indien, selensky, euro, china...
#
#                                  Representative_Docs  \
# 0  [Im Sommer hat Selensky versucht, die von den ...
# 1  [Die New York Times versucht seit langem vor G...
# 2  [Ich berichte in drei Artikeln über die Wahl i...
# 3  [Ich bin zufällig auf einen Artikel eines russ...
# 4  [Letzte Woche war es, als würde die ganze Welt...
#
#                                          Top_n_words  Probability  \
# 0  nabu - selensky - timoschenko - selenskys - je...      1.00000
# 1  merkel - minsker - 2021 - minsker abkommen - a...      1.00000
# 2  moldawien - wahlen - wahl - moldawischen - san...      1.00000
# 3  cia - reitschuster - modi - indien - entwickel...      0.46664
# 4  vermögenswerte - indien - selensky - euro - ch...      0.00000
#
#    Representative_document
# 0                     True
# 1                     True
# 2                    False
# 3                    False
# 4                    False

# %%
Antispiegel_topics = df_clean.reset_index().merge(
    doc_info[["original_index", "Topic", "Name", "Probability"]],
    left_on="index",
    right_on="original_index",
    how="left",
)

# %%
Antispiegel_topics.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           565 non-null    int64
#  1   Date            565 non-null    datetime64[us]
#  2   Title           565 non-null    object
#  3   Summary         564 non-null    object
#  4   Text            565 non-null    str
#  5   URL             565 non-null    object
#  6   source          565 non-null    str
#  7   source_file     565 non-null    str
#  8   original_index  565 non-null    int64
#  9   Topic           565 non-null    int64
#  10  Name            565 non-null    str
#  11  Probability     565 non-null    float64
# dtypes: datetime64[us](1), float64(1), int64(3), object(3), str(4)
# memory usage: 53.1+ KB

# %%
fig, ax = plt.subplots(figsize=(14, 10))

# Exclude topic -1 (outliers) and get top 20 topics by count
topic_counts = topic_info[topic_info['Topic'] != -1].copy()
topic_counts = topic_counts.nlargest(20, 'Count').sort_values('Count', ascending=True)

ax.barh(topic_counts['Name'], topic_counts['Count'], color='#1f77b4', edgecolor='white')

ax.set_xlabel('Number of Documents', fontsize=12)
ax.set_ylabel('Topic', fontsize=12)
ax.set_title('Antispiegel BERTopic: Document Count per Topic (Top 20)', fontsize=14)
ax.grid(axis='x', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Prepare data for topics over time using the final reduced model if it already exists.
# Re-run this cell after outlier reduction to pick up `result_as_reduced`.
topic_time_result = result_as_reduced if "result_as_reduced" in globals() else result_as

topic_info_time = topic_time_result["topic_info"].copy()
prepared_docs_time = topic_time_result["prepared_documents"]
date_col = "Date" if "Date" in prepared_docs_time.columns else "day"
prepared_dates = pd.to_datetime(prepared_docs_time[date_col], errors="coerce")
valid_time_mask = prepared_dates.notna().tolist()

docs_for_time = [doc for doc, ok in zip(topic_time_result["docs"], valid_time_mask) if ok]
topics_for_time = [topic for topic, ok in zip(topic_time_result["topics"], valid_time_mask) if ok]
timestamps_for_time = [ts for ts in prepared_dates.tolist() if pd.notna(ts)]

topics_over_time = topic_time_result["topic_model"].topics_over_time(
    docs_for_time,
    timestamps_for_time,
    topics=topics_for_time,
    nr_bins=6,
)

topic_info_non_outliers = topic_info_time.loc[topic_info_time["Topic"] != -1].copy()
if "DisplayTopic" in topic_info_non_outliers.columns:
    top_10_topics = topic_info_non_outliers.nsmallest(10, "DisplayTopic")["Topic"].tolist()
    label_map = dict(zip(topic_info_time["Topic"], topic_info_time["DisplayLabel"]))
else:
    top_10_topics = topic_info_non_outliers.nlargest(10, "Count")["Topic"].tolist()
    label_map = dict(zip(topic_info_time["Topic"], topic_info_time["Name"]))

topics_over_time_filtered = topics_over_time[topics_over_time["Topic"].isin(top_10_topics)]

fig, ax = plt.subplots(figsize=(14, 8))
sns.set_theme(style="whitegrid", context="talk")

palette = sns.color_palette("husl", n_colors=10)

for i, topic in enumerate(top_10_topics):
    topic_data = topics_over_time_filtered[topics_over_time_filtered["Topic"] == topic]
    label = label_map.get(topic, f"Topic {topic}")
    ax.plot(
        topic_data["Timestamp"],
        topic_data["Frequency"],
        marker="o",
        linewidth=2.5,
        markersize=8,
        color=palette[i],
        label=label,
    )

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel("Number of Documents", fontsize=14)
ax.set_title("Antispiegel: Top 10 Topics Over Time (Aug 2025 - Jan 2026)", fontsize=16, fontweight="bold")
ax.legend(title="Topic", bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=10)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 6it [00:10,  1.79s/it]

# %%
# Final BERTopic comparison table: all topics + representative words
from IPython.display import display

topics_comparison_df = topic_info[["Topic", "Name", "Count"]].copy()

def _representative_words_for_topic(topic_id: int) -> str:
    terms = result["topic_model"].get_topic(int(topic_id)) or []
    return ", ".join(word for word, _ in terms)

topics_comparison_df["Representative_Words"] = topics_comparison_df["Topic"].apply(_representative_words_for_topic)
topics_comparison_df = topics_comparison_df.sort_values("Topic").reset_index(drop=True)

with pd.option_context("display.max_colwidth", None, "display.width", 220):
    display(topics_comparison_df)
# Out:
#     Topic                                                               Name  Count                                                                                                               Representative_Words
# 0      -1                             -1_vermögenswerte_indien_selensky_euro     90                      vermögenswerte, indien, selensky, euro, china, frankreich, ungarn, brics, russischen vermögenswerte, poseidon
# 1       0                       0_selensky_sicherheitsgarantien_axios_dürfte     27                      selensky, sicherheitsgarantien, axios, dürfte, waffenstillstand, frieden, truppen, fordert, budapest, donbass
# 2       1                               1_selensky_nabu_minditsch_korruption     25                       selensky, nabu, minditsch, korruption, selenskys, maidan, jermak, kolomoisky, energoatom, korruptionsskandal
# 3       2                               2_moldawien_wahlen_wahl_moldawischen     16                              moldawien, wahlen, wahl, moldawischen, sandu, moldawische, moldawiens, chisinau, gagausen, opposition
# 4       3                                      3_gaza_netanjahu_hamas_israel     15                         gaza, netanjahu, hamas, israel, israelische, israelischen, gazastreifen, friedensrat, charta, vorsitzenden
# 5       4                           4_aserbaidschan_iran_georgien_georgische     13                aserbaidschan, iran, georgien, georgische, armenien, georgischen, region, aserbaidschanische, südossetien, starlink
# 6       5                                       5_ungarn_gps_druschba_steele     13                                              ungarn, gps, druschba, steele, angriffe, pipeline, slowakei, mig, ölpipeline, störung
# 7       6                                  6_polen_polnische_polnischen_nord     12                                      polen, polnische, polnischen, nord, nord stream, stream, ostsee, warschau, pipelines, gericht
# 8       7                                        7_drohnen_akw_polen_vorfall     11                                                 drohnen, akw, polen, vorfall, polnischen, nacht, luftraum, drohne, iaeo, polnische
# 9       8                              8_nabu_selensky_timoschenko_selenskys     11                                            nabu, selensky, timoschenko, selenskys, jermak, korruption, center, afd, dossier, group
# 10      9                                   9_merz_koalition_macron_willigen     11                             merz, koalition, macron, willigen, koalition willigen, euro, milliarden euro, selensky, davos, bericht
# 11     10                      10_feind_wladiwostok_kommission_eu kommission     10                    feind, wladiwostok, kommission, eu kommission, tusk, lissabon wladiwostok, valdai, beitritt, lissabon, geändert
# 12     11                           11_china_chinesischen_taiwan_chinesische     10                                              china, chinesischen, taiwan, chinesische, peking, chinas, xi, tiktok, chinesen, japan
# 13     12                                    12_cia_reitschuster_modi_indien     10                                    cia, reitschuster, modi, indien, entwickelt, biowaffen, indischen, websites, netzwerk, indische
# 14     13                    13_strategie_europas_uno_staats regierungschefs     10                strategie, europas, uno, staats regierungschefs, staats, regierungschefs, grünen, sicherheitsstrategie, co2, reform
# 15     14                            14_punkt_biden_friedensplan_trumps plan     10                   punkt, biden, friedensplan, trumps plan, akt, militärausgaben, abkommen, wirtschaft, trumps friedensplan, bayrou
# 16     15                                  15_shutdown_demokraten_haus_weiße     10                               shutdown, demokraten, haus, weiße, grönland, weiße haus, us präsident, dmitrijew, dialog, antwortete
# 17     16                   16_macron_lecornu_premierminister_gewerkschaften      9                    macron, lecornu, premierminister, gewerkschaften, merz, palästina, frankreich, fernsehen, scholz, bundeskanzler
# 18     17                           17_merz_bundeskanzler_sozialstaat_indien      9                          merz, bundeskanzler, sozialstaat, indien, friedrich merz, friedrich, cdu, ausgleich, macron, finanzierbar
# 19     18                                           18_gas_lng_studie_winter      9                                               gas, lng, studie, winter, 2021, pipelinegas, gasspeicher, preise, ungarn, russisches
# 20     19              19_österreich_neutralität_präventivschlag_österreichs      9           österreich, neutralität, präventivschlag, österreichs, schiffe, sowjetische, konzept, admiral, österreichischen, dragone
# 21     20                           20_grönland_dänemark_dänischen_grönlands      9                               grönland, dänemark, dänischen, grönlands, dänische, insel, arktis, kopenhagen, grönländer, dänemarks
# 22     21                                     21_china_punkt_macron_wadephul      8                              china, punkt, macron, wadephul, friedensplan, sicherheitsgarantien, gaza, dürfte, selensky, europäern
# 23     22                             22_obama_demokraten_2016_geheimdienste      8                                                      obama, demokraten, 2016, geheimdienste, haus, new, weißen, wahl, fbi, witkoff
# 24     23                                  23_grönland_kanada_dänemark_davos      8                                 grönland, kanada, dänemark, davos, strafzölle, kanadas, arktis, grönland frage, strafzöllen, zölle
# 25     24                         24_eu kommission_kommission_francken_leyen      8                                   eu kommission, kommission, francken, leyen, kallas, brüssel, dubrowin, europas, truppen, zeitung
# 26     25                          25_belgien_gelder_vermögenswerte_politico      8  belgien, gelder, vermögenswerte, politico, russischen gelder, kommission, eu staaten, eu kommission, reparationskredit, belgische
# 27     26                                26_ukrainer_front_drohnen_ukrainern      8      ukrainer, front, drohnen, ukrainern, flüchtlinge, milliarden us, armee, rekrutierungszentren, us dollar, milliarden us dollar
# 28     27                                 27_soz_china_zusammenarbeit_gipfel      8                                   soz, china, zusammenarbeit, gipfel, afrika, parade, g20, afrikanischen, globalisierung, globalen
# 29     28                              28_raketen_burevestnik_patriot_rakete      7                               raketen, burevestnik, patriot, rakete, poseidon, marschflugkörper, reichweite, kh, iskander, kinzhal
# 30     29                     29_venezuela_maduro_venezuelas_venezolanischen      7                       venezuela, maduro, venezuelas, venezolanischen, venezolanische, philippinen, caracas, iran, israel, invasion
# 31     30                               30_ndr_rostock_atomwaffen_britischen      7                             ndr, rostock, atomwaffen, britischen, nuklearen, stationiert, sentry, baltic, hauptquartier, flugzeuge
# 32     31                    31_festnahmen_gesetz_werbung_politische werbung      7   festnahmen, gesetz, werbung, politische werbung, bundesregierung, nachrichten, meinungsfreiheit, polizei, demokratie, äußerungen
# 33     32                                    32_reiber_taiwan_china_schreibt      7                                                      reiber, taiwan, china, schreibt, indien, leser, kapitel, ki, japan, schreiben
# 34     33                                  33_hebel_frau_lieder_chodorkowski      7                              hebel, frau, lieder, chodorkowski, fsb, petersburg, schreibt, lied, kriegspropaganda, bundesregierung
# 35     34                              34_fernen_fernen osten_osten_regionen      7                              fernen, fernen osten, osten, regionen, interessen, region, fernen ostens, valdai, ostens, sowjetunion
# 36     35                                 35_bip_pfister_experten_wirtschaft      6            bip, pfister, experten, wirtschaft, russland experten, endlich, messen, bip kaufkraftparität, technologisch, propaganda
# 37     36                               36_whistleblower_blm_pfister_bericht      6               whistleblower, blm, pfister, bericht, demokraten, schiff, vereinigten staaten, briefwahl, us demokraten, vereinigten
# 38     37                           37_uschakow_lawrow_besprochen_gesprochen      6                               uschakow, lawrow, besprochen, gesprochen, formulierung, kreml, präsident trump, wort, sprache, krise
# 39     38                                  38_israel_katar_israelische_hamas      6                                  israel, katar, israelische, hamas, israels, iran, palästinensischen, gazastreifen, netanjahu, tel
# 40     39                     39_raketen_tomahawk_tomahawks_tomahawk raketen      6          raketen, tomahawk, tomahawks, tomahawk raketen, lieferung, reichweite, tschukotka, liefern, oreschnik, lieferung tomahawk
# 41     40  40_vertrag_mittelstreckenraketen_kurz mittelstreckenraketen_start      6        vertrag, mittelstreckenraketen, kurz mittelstreckenraketen, start, raketen, new start, stationierung, inf, new, inf vertrag
# 42     41                       41_wahllokale_moldawien_sandu_wahlkommission      5                    wahllokale, moldawien, sandu, wahlkommission, wahl, moldawische, gagausien, moldawischen, moldawier, opposition
# 43     42                            42_bellingcat_al_buch_westlichen medien      5                                bellingcat, al, buch, westlichen medien, ermordung, sullivan, jazeera, al jazeera, beweise, getötet
# 44     43                                    43_mittelmeer_absatz_türkei_gas      5                                  mittelmeer, absatz, türkei, gas, weltordnung, öl, israel, venezuelas, östlichen mittelmeer, china
# 45     44                                 44_baud_jacques baud_jacques_alina      5                              baud, jacques baud, jacques, alina, sanktioniert, lipp, alina lipp, eu sanktionen, bestraft, anwältin
# 46     45        45_streitkräfte_ukrainischen streitkräfte_cia_krasnoarmejsk      5                         streitkräfte, ukrainischen streitkräfte, cia, krasnoarmejsk, selensky, stadt, ss, truppen, front, kupjansk
# 47     46                            46_tanker_meer_schwarzen meer_schwarzen      5                                          tanker, meer, schwarzen meer, schwarzen, angriffe, el, angegriffen, cpc, spanien, schiffe
# 48     47                                47_meloni_reitschuster_rom_puschkow      5                      meloni, reitschuster, rom, puschkow, generalversammlung, italienische, ministerpräsidentin, italien, un, saal
# 49     48                                 48_kirk_charlie_charlie kirk_kirks      4                               kirk, charlie, charlie kirk, kirks, robinson, mord, meinungsfreiheit, amerika, konservativen, kimmel
# 50     49                            49_merkel_minsker_2021_minsker abkommen      4                          merkel, minsker, 2021, minsker abkommen, abkommen, donbass, interview, november 2021, kommission, merkels
# 51     50       50_eu gipfel_vermögenswerte_gipfel_russischen vermögenswerte      4        eu gipfel, vermögenswerte, gipfel, russischen vermögenswerte, leyen, belgien, gipfels, kommission, eu kommission, eu länder
# 52     51                                         51_öl_gas_atomtests_öl gas      4                                    öl, gas, atomtests, öl gas, forderungen, china, atomwaffentests, atomwaffen, russisches, testen
# 53     52              52_gas_preise_industriellen_militärisch industriellen      4              gas, preise, industriellen, militärisch industriellen, euro, kubikmeter, rheinmetall, militärisch, markt, heizperiode
# 54     53                                      53_bbc_blm_twitter_demokraten      4                                                      bbc, blm, twitter, demokraten, soros, proteste, lüge, ice, gewalt, trump habe
# 55     54                               54_merz_merkel_schröder_deutschlands      4                 merz, merkel, schröder, deutschlands, kanzler, chodorkowski, scholz, globalen, altersarmut, deutschen europäischen
# 56     55                           55_vermögenswerte_belgien_de wever_wever      4       vermögenswerte, belgien, de wever, wever, belgische, gelder, euroclear, russischen vermögenswerte, kommission, eu kommission
# 57     56                     56_wahlen_china_sicherheitsstrategie_strategie      4     wahlen, china, sicherheitsstrategie, strategie, französische, moldawien, französischen, einmischung, frankreich, konzentrieren
# 58     57                  57_unabhängigkeitserklärung_völkerrecht_kosovo_un      4                         unabhängigkeitserklärung, völkerrecht, kosovo, un, kudrytsky, identität, holocaust, nazi, krim, referenden

# %%
# BERTopic v2 run: full text first, then title-only
from bertopic_pipelinev2 import (
    BERTopicV2Config,
    BERTopicV2ConfigTitle,
    run_bertopic_pipeline,
)

result_full_text_v2 = run_bertopic_pipeline(
    df=df_clean,
    text_col="Text",
    config=BERTopicV2Config(),
    id_col="URL",
    source_name="Antispiegel",
)

result_title_v2 = run_bertopic_pipeline(
    df=df_clean,
    text_col="Title",
    config=BERTopicV2ConfigTitle(),
    id_col="URL",
    source_name="Antispiegel",
)

print(
    f"v2 full-text docs: {len(result_full_text_v2['docs']):,} | "
    f"v2 title docs: {len(result_title_v2['docs']):,}"
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[109], line 8
#       1 # BERTopic v2 run: full text first, then title-only
#       2 from bertopic_pipelinev2 import (
#       3     BERTopicV2Config,
#       4     BERTopicV2ConfigTitle,
#       5     run_bertopic_pipeline,
#       6 )
# ----> 8 result_full_text_v2 = run_bertopic_pipeline(
#       9     df=df_clean,
#      10     text_col="Text",
#      11     config=BERTopicV2Config(),
#      12     id_col="URL",
#      13     source_name="Antispiegel",
#      14 )
#      16 result_title_v2 = run_bertopic_pipeline(
#      17     df=df_clean,
#      18     text_col="Title",
#    (...)     21     source_name="Antispiegel",
#      22 )
#      24 print(
#      25     f"v2 full-text docs: {len(result_full_text_v2['docs']):,} | "
#      26     f"v2 title docs: {len(result_title_v2['docs']):,}"
#      27 )
#
# File ~/Dev/Thesis/1a_BERTopic/bertopic_pipelinev2.py:297, in run_bertopic_pipeline(df, text_col, config, id_col, source_name, stop_words, embedding_model)
#     294 except ImportError:
#     295     pass
# --> 297 topic_model = build_topic_model(
#     298     config,
#     299     stop_words=stop_words,
#     300     embedding_model=embedding_model,
#     301 )
#     302 topics, probs = topic_model.fit_transform(docs)
#     304 topic_info = topic_model.get_topic_info()
#
# File ~/Dev/Thesis/1a_BERTopic/bertopic_pipelinev2.py:253, in build_topic_model(config, stop_words, embedding_model)
#     245     bertopic_module = _require_dependency("bertopic", "pip install bertopic")
#     246 BERTopic = bertopic_module.BERTopic
#     248 return BERTopic(
#     249     embedding_model=embedding_model or build_embedding_model(config),
#     250     vectorizer_model=build_vectorizer(config, stop_words=stop_words),
#     251     umap_model=build_umap_model(config),
#     252     hdbscan_model=build_hdbscan_model(config),
# --> 253     representation_model=build_representation_model(config),
#     254     language=config.language,
#     255     top_n_words=config.top_n_words,
#     256     nr_topics=config.nr_topics,
#     257     calculate_probabilities=config.calculate_probabilities,
#     258     low_memory=config.low_memory,
#     259     verbose=True,
#     260 )
#
# File ~/Dev/Thesis/1a_BERTopic/bertopic_pipelinev2.py:232, in build_representation_model(config)
#     230     representation_module = _require_dependency("bertopic.representation", "pip install bertopic")
#     231 PartOfSpeech = representation_module.PartOfSpeech
# --> 232 return PartOfSpeech(config.spacy_model_name)
#
# File ~/Dev/Thesis/.venv/lib/python3.11/site-packages/bertopic/_utils.py:103, in NotInstalled.__call__(self, *args, **kwargs)
#     102 def __call__(self, *args, **kwargs):
# --> 103     raise ModuleNotFoundError(self.msg)
#
# ModuleNotFoundError: In order to use Part of Speech with Spacy you will need to install via;
#
# pip install bertopic[spacy]

# %%
from pathlib import Path
import pandas as pd

def resolve_project_root() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in (cwd, cwd.parent):
        if (candidate / "data" / "raw" / "Alternative Medien").exists():
            return candidate
    raise FileNotFoundError("Could not locate project root containing data/raw/Alternative Medien")

def read_csv_resilient(csv_path: Path) -> pd.DataFrame:
    for encoding in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            return pd.read_csv(
                csv_path,
                encoding=encoding,
                low_memory=False,
                on_bad_lines="skip",
            )
        except Exception:
            pass

    for encoding in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            return pd.read_csv(
                csv_path,
                encoding=encoding,
                sep=None,
                engine="python",
                low_memory=False,
                on_bad_lines="skip",
            )
        except Exception:
            pass

    raise ValueError(f"Could not read: {csv_path}")

PROJECT_ROOT = resolve_project_root()
BASE_DIR = PROJECT_ROOT / "data" / "raw" / "Alternative Medien"

SOURCE_NAME = "Antispiegel"
SOURCE_DIR = BASE_DIR / SOURCE_NAME
csv_files = sorted(SOURCE_DIR.rglob("*.csv"))

parts = []
for csv_file in csv_files:
    part = read_csv_resilient(csv_file)
    part["source"] = SOURCE_NAME
    part["source_file"] = csv_file.name
    parts.append(part)

df = pd.concat(parts, ignore_index=True, sort=False) if parts else pd.DataFrame()

# Keep a dedicated Text column and normalize expected column aliases.
if "Text" not in df.columns and "article_text" in df.columns:
    df["Text"] = df["article_text"]
if "title" not in df.columns and "Title" in df.columns:
    df["title"] = df["Title"]
if "date" not in df.columns and "Date" in df.columns:
    df["date"] = df["Date"]
if "url" not in df.columns and "URL" in df.columns:
    df["url"] = df["URL"]

print(f"Loaded {len(df)} rows from {len(csv_files)} file(s) in {SOURCE_DIR}")

# %%
from pathlib import Path
import sys

def resolve_project_root() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in (cwd, *cwd.parents):
        if (candidate / "1a_BERTopic").exists():
            return candidate
    raise FileNotFoundError("Could not locate project root containing 1a_BERTopic")

project_root = resolve_project_root()
module_root = project_root / "1a_BERTopic"

if str(module_root) not in sys.path:
    sys.path.insert(0, str(module_root))

# %%
from bertopic_config import BERTopicConfig, title_config
from bertopic_pipeline import run_bertopic_pipeline

# %%
# Prepare Antispiegel dataframe for topic modeling
df_clean = df[["title", "date", "url", "Text"]].copy()
df_clean["day"] = pd.to_datetime(df_clean["date"], errors="coerce")

df_clean["Text"] = (
    df_clean["Text"]
    .astype("string")
    .str.replace("\n", " ", regex=False)
    .str.strip()
)

df_clean["title"] = (
    df_clean["title"]
    .astype("string")
    .str.replace("\n", " ", regex=False)
    .str.strip()
)

df_clean = df_clean.dropna(subset=["day", "url", "Text"]).copy()

df_clean = df_clean[
    (df_clean["day"] >= "2025-08-01") & (df_clean["day"] <= "2026-01-31")
].copy()

print(f"Rows prepared for BERTopic: {len(df_clean):,}")
df_clean[["title", "Text", "day", "url"]].head()

# %%
# BERTopic on full article text
result = run_bertopic_pipeline(
    df=df_clean,
    text_col="Text",
    config=BERTopicConfig(hdbscan_min_cluster_size=25),
    id_col="url",
    source_name="Antispiegel",
)

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)

topic_info = result["topic_info"].copy()
topic_info["Representation_str"] = topic_info["Representation"].apply(
    lambda x: ", ".join(x) if isinstance(x, (list, tuple)) else str(x)
)

topic_info[["Topic", "Count", "Name", "Representation_str"]].head(50)

# %%
# BERTopic quality metrics
import re
import numpy as np
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel


def get_topic_words(topic_model, top_k=10, include_outlier=False):
    topic_info = topic_model.get_topic_info()
    topic_ids = topic_info["Topic"].tolist()
    if not include_outlier:
        topic_ids = [t for t in topic_ids if t != -1]

    topics = []
    for topic_id in topic_ids:
        terms = topic_model.get_topic(int(topic_id)) or []
        words = [w for w, _ in terms[:top_k]]
        if words:
            topics.append(words)
    return topics


def evaluate_bertopic(docs, topic_model, top_k=10):
    topics = get_topic_words(topic_model, top_k=top_k, include_outlier=False)
    if not topics:
        return {"coherence_npmi": np.nan, "topic_diversity": np.nan}

    texts = [re.findall(r"(?u)\b\w\w+\b", str(doc).lower()) for doc in docs]
    dictionary = Dictionary(texts)

    topics_for_coherence = [[w for w in t if w in dictionary.token2id] for t in topics]
    topics_for_coherence = [t for t in topics_for_coherence if len(t) >= 2]

    if not topics_for_coherence:
        coherence_npmi = np.nan
    else:
        cm = CoherenceModel(
            topics=topics_for_coherence,
            texts=texts,
            dictionary=dictionary,
            coherence="c_npmi",
        )
        coherence_npmi = cm.get_coherence()

    all_words = [w for t in topics for w in t]
    topic_diversity = len(set(all_words)) / (len(topics) * top_k)

    return {
        "coherence_npmi": coherence_npmi,
        "topic_diversity": topic_diversity,
        "num_topics": len(topics),
        "top_k": top_k,
    }


metrics = evaluate_bertopic(
    docs=result["docs"],
    topic_model=result["topic_model"],
    top_k=10,
)
metrics

# %%
doc_info = result["doc_info"].copy()

# Compact topic overview: number of linked documents per topic (no long text columns).
group_cols = [c for c in ["Topic", "Name"] if c in doc_info.columns]
doc_info_overview = (
    doc_info.groupby(group_cols, dropna=False)
    .size()
    .reset_index(name="Doc_Count")
    .sort_values("Doc_Count", ascending=False)
    .reset_index(drop=True)
)

if "Probability" in doc_info.columns:
    avg_prob = (
        doc_info.groupby(group_cols, dropna=False)["Probability"]
        .mean()
        .reset_index(name="Avg_Probability")
    )
    doc_info_overview = doc_info_overview.merge(avg_prob, on=group_cols, how="left")
    doc_info_overview["Avg_Probability"] = doc_info_overview["Avg_Probability"].round(3)

if "Name" in doc_info_overview.columns:
    doc_info_overview["Name"] = doc_info_overview["Name"].astype("string").str.slice(0, 60)

doc_info_overview

# %%
antispiegel_topics = df_clean.reset_index().merge(
    doc_info[["original_index", "Topic", "Name", "Probability"]],
    left_on="index",
    right_on="original_index",
    how="left",
)

# Compact overview display (no full article text column).
display_cols = [c for c in ["day", "title", "Topic", "Name", "Probability"] if c in antispiegel_topics.columns]
antispiegel_topics[display_cols].head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(14, 10))

# Exclude topic -1 (outliers) for cleaner visualization
topic_counts = topic_info[topic_info["Topic"] != -1].copy()
topic_counts = topic_counts.nlargest(20, "Count").sort_values("Count", ascending=True)

ax.barh(topic_counts["Name"], topic_counts["Count"], color="#1f77b4", edgecolor="white")

ax.set_xlabel("Number of Documents", fontsize=12)
ax.set_ylabel("Topic", fontsize=12)
ax.set_title("Antispiegel BERTopic: Document Count per Topic", fontsize=14)
ax.grid(axis="x", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Prepare data for topics over time using the final reduced model if it already exists.
# Re-run this cell after outlier reduction to pick up `result_as_reduced`.
topic_time_result = result_as_reduced if "result_as_reduced" in globals() else result_as

topic_info_time = topic_time_result["topic_info"].copy()
prepared_docs_time = topic_time_result["prepared_documents"]
date_col = "Date" if "Date" in prepared_docs_time.columns else "day"
prepared_dates = pd.to_datetime(prepared_docs_time[date_col], errors="coerce")
valid_time_mask = prepared_dates.notna().tolist()

docs_for_time = [doc for doc, ok in zip(topic_time_result["docs"], valid_time_mask) if ok]
topics_for_time = [topic for topic, ok in zip(topic_time_result["topics"], valid_time_mask) if ok]
timestamps_for_time = [ts for ts in prepared_dates.tolist() if pd.notna(ts)]

topics_over_time = topic_time_result["topic_model"].topics_over_time(
    docs_for_time,
    timestamps_for_time,
    topics=topics_for_time,
    nr_bins=6,
)

topic_info_non_outliers = topic_info_time.loc[topic_info_time["Topic"] != -1].copy()
if "DisplayTopic" in topic_info_non_outliers.columns:
    top_10_topics = topic_info_non_outliers.nsmallest(10, "DisplayTopic")["Topic"].tolist()
    label_map = dict(zip(topic_info_time["Topic"], topic_info_time["DisplayLabel"]))
else:
    top_10_topics = topic_info_non_outliers.nlargest(10, "Count")["Topic"].tolist()
    label_map = dict(zip(topic_info_time["Topic"], topic_info_time["Name"]))

topics_over_time_filtered = topics_over_time[topics_over_time["Topic"].isin(top_10_topics)]

fig, ax = plt.subplots(figsize=(14, 8))
sns.set_theme(style="whitegrid", context="talk")

palette = sns.color_palette("husl", n_colors=10)

for i, topic in enumerate(top_10_topics):
    topic_data = topics_over_time_filtered[topics_over_time_filtered["Topic"] == topic]
    label = label_map.get(topic, f"Topic {topic}")
    ax.plot(
        topic_data["Timestamp"],
        topic_data["Frequency"],
        marker="o",
        linewidth=2.5,
        markersize=8,
        color=palette[i],
        label=label,
    )

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel("Number of Documents", fontsize=14)
ax.set_title("Antispiegel: Top 10 Topics Over Time (Aug 2025 - Jan 2026)", fontsize=16, fontweight="bold")
ax.legend(title="Topic", bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=10)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
