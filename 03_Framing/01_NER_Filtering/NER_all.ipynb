# %% [markdown]
# # NER — Corpus-Wide Entity Extraction
#
# Runs Named Entity Recognition on the full German corpus using the Flair model `flair/ner-german-large`. Cleans and deduplicates article text, extracts high-confidence `PER`, `ORG`, and `LOC` spans (score ≥ 0.85), normalizes surface forms (genitive-s stripping, name canonicalization, surname expansion), and writes a corpus-level entity-counts table. This artifact informed the curation of the mainstream-media filter list used in Mechanism 2; it is not itself the runtime filter (the runtime filter is a regex over outlet names plus mainstream-media synonyms, implemented in `../02_Framing_Classification_Run/`).

# %%
import json
from pathlib import Path

import pandas as pd
from IPython.display import display

df = pd.read_csv("df_combined.csv")

print(f"Shape: {df.shape}")
display(df.head(3))

# %% [markdown]
# ## Step 1: Prepare the text
#
# Clean `Title` and `Text`, keep a stable `row_id`, and combine title plus article body into one `document_text` field.

# %%
import hashlib
import html
import re
from collections import defaultdict

# --------------------------------------------------
# 1. CLEAN THE TEXT BEFORE NER
# --------------------------------------------------

SOURCE_BOILERPLATE = {
    "Antispiegel": [
        r"Ende der Übersetzung\.?$",
        r"Man kann .*?(?:auf X|auf Telegram).*? folgen\.?$",
    ],
    "Compact": [
        r"Hier bestellen!?\.?$",
        r"Jetzt bestellen!?\.?$",
        r"Hier mehr erfahren\.?$",
        r"zum einmaligen Angebotspreis .*?$",
    ],
    "Deutschlandkurier": [
        r"Bitte beachten Sie, dass dabei Daten an Drittanbieter weitergegeben werden\..*$",
    ],
    "Nius": [
        r"Hier geht['’]s direkt zur Aufzeichnung.*$",
        r"Ab sofort auch in .*?$",
    ],
    "RT_de": [
        r"Ende der Übersetzung\.?$",
        r"Man kann .*?(?:auf X|auf Telegram).*? folgen\.?$",
    ],
    "Tagesschau": [
        r"Über dieses Thema berichtete .*?(?:Uhr\.?)?$",
        r"\|\s*\d{2}\.\d{2}\.\d{4}\s*\|\s*\d{2}:\d{2}\s*Uhr$",
    ],
    "Tichys_Einblick": [
        r"^Ich bin damit einverstanden, dass mir von (?:Youtube|Twitter) .*? werden\.\s*",
        r"Mit Ihrem Einkauf im TE-Shop .*?$",
        r"unterstützen Sie den unabhängigen Journalismus von Tichys Einblick!.*$",
    ],
}

def normalize_unicode(text: str) -> str:
    text = html.unescape(str(text))
    replacements = {
        "\u00a0": " ",
        "\u200b": " ",
        "’": "'",
        "‘": "'",
        "´": "'",
        "`": "'",
        "“": '"',
        "”": '"',
        "–": "-",
        "—": "-",
        "…": "...",
        "￼": " ",
    }
    for old, new in replacements.items():
        text = text.replace(old, new)
    text = text.replace("\r\n", "\n").replace("\r", "\n")
    return text

def strip_source_boilerplate(text: str, source: str) -> str:
    for pattern in SOURCE_BOILERPLATE.get(source, []):
        text = re.sub(pattern, " ", text, flags=re.IGNORECASE)
    return text

def clean_article_text(text: str, source: str) -> str:
    text = normalize_unicode(text)
    text = re.sub(r"^#+\s*", "", text)
    text = strip_source_boilerplate(text, source)
    text = re.sub(r"https?://\S+|www\.\S+", " ", text)
    text = re.sub(r"\b\S+@\S+\b", " ", text)
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    return text.strip()

work = df.copy()

work["Title_clean"] = [
    clean_article_text(title, source)
    for title, source in zip(work["Title"].fillna(""), work["source"].fillna(""))
]

work["Text_clean"] = [
    clean_article_text(text, source)
    for text, source in zip(work["Text"].fillna(""), work["source"].fillna(""))
]

# For the full-text run, use the body text as the main NER input.
# If you want title context too, prepend the title WITHOUT "Title:" / "Text:" labels.
work = work[work["Title_clean"].str.len() > 0].copy()
work["document_text"] = work["Title_clean"]
# optional:
# work["document_text"] = (work["Title_clean"] + "\n\n" + work["Text_clean"]).str.strip()

# Deduplicate only for inference speed, not for the final analysis.
work["doc_hash"] = work["document_text"].map(
    lambda x: hashlib.md5(x.encode("utf-8")).hexdigest()
)
run_df = work.drop_duplicates("doc_hash").copy()

print(f"Rows kept for analysis: {len(work):,}")
print(f"Unique texts sent to NER: {len(run_df):,}")
# Out:
# Rows kept for analysis: 20,440
# Unique texts sent to NER: 20,426

# %% [markdown]
# ## Step 2: Load the Flair NER model
#
# If Flair is not installed yet, run the install command once, restart the kernel, and then run the cell below.
#
# ```python
# %pip install flair
# ```

# %%
# !pip install flair
# Out:
# Collecting flair
#   Downloading flair-0.15.1-py3-none-any.whl.metadata (12 kB)
# Collecting boto3>=1.20.27 (from flair)
#   Downloading boto3-1.42.70-py3-none-any.whl.metadata (6.7 kB)
# Collecting conllu<5.0.0,>=4.0 (from flair)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl.metadata (19 kB)
# Collecting deprecated>=1.2.13 (from flair)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting ftfy>=6.1.0 (from flair)
#   Using cached ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting gdown>=4.4.0 (from flair)
#   Downloading gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (1.6.0)
# Collecting langdetect>=1.0.9 (from flair)
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Collecting lxml>=4.8.0 (from flair)
#   Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib>=2.2.3 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (3.10.8)
# Collecting more-itertools>=8.13.0 (from flair)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting mpld3>=0.3 (from flair)
#   Downloading mpld3-0.5.12-py3-none-any.whl.metadata (5.3 kB)
# Collecting pptree>=3.1 (from flair)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (2.9.0.post0)
# Collecting pytorch-revgrad>=0.2.0 (from flair)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (2026.2.28)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (1.8.0)
# Collecting segtok>=1.5.11 (from flair)
#   Downloading segtok-1.5.11-py3-none-any.whl.metadata (9.0 kB)
# Collecting sqlitedict>=2.0.0 (from flair)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tabulate>=0.8.10 (from flair)
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: torch>=1.13.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (2.10.0)
# Requirement already satisfied: tqdm>=4.63.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from flair) (4.67.3)
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair)
#   Downloading transformer_smaller_training_vocab-0.4.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting transformers<5.0.0,>=4.25.0 (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Collecting wikipedia-api>=0.5.7 (from flair)
#   Downloading wikipedia_api-0.10.2-py3-none-any.whl.metadata (21 kB)
# Collecting bioc<3.0.0,>=2.0.0 (from flair)
#   Downloading bioc-2.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting jsonlines>=1.2.0 (from bioc<3.0.0,>=2.0.0->flair)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting intervaltree (from bioc<3.0.0,>=2.0.0->flair)
#   Downloading intervaltree-3.2.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting docopt (from bioc<3.0.0,>=2.0.0->flair)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (3.25.0)
# Collecting huggingface-hub>=0.10.0 (from flair)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (6.0.3)
# Requirement already satisfied: requests in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.10.0->flair) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.10.0->flair) (1.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.10.0->flair) (4.15.0)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair)
#   Downloading sentencepiece-0.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting protobuf (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair)
#   Downloading protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting botocore<1.43.0,>=1.42.70 (from boto3>=1.20.27->flair)
#   Downloading botocore-1.42.70-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.27->flair)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3>=1.20.27->flair)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.70->boto3>=1.20.27->flair) (2.6.3)
# Requirement already satisfied: six>=1.5 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->flair) (1.17.0)
# Collecting wrapt<3,>=1.10 (from deprecated>=1.2.13->flair)
#   Downloading wrapt-2.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Requirement already satisfied: wcwidth in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from ftfy>=6.1.0->flair) (0.5.3)
# Requirement already satisfied: beautifulsoup4 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from gdown>=4.4.0->flair) (4.14.3)
# Requirement already satisfied: attrs>=19.2.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from jsonlines>=1.2.0->bioc<3.0.0,>=2.0.0->flair) (25.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from matplotlib>=2.2.3->flair) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from matplotlib>=2.2.3->flair) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from matplotlib>=2.2.3->flair) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from matplotlib>=2.2.3->flair) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from matplotlib>=2.2.3->flair) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from matplotlib>=2.2.3->flair) (3.3.2)
# Requirement already satisfied: jinja2 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from mpld3>=0.3->flair) (3.1.6)
# Requirement already satisfied: scipy>=1.10.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from scikit-learn>=1.0.2->flair) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from scikit-learn>=1.0.2->flair) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from scikit-learn>=1.0.2->flair) (3.6.0)
# Requirement already satisfied: setuptools in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from torch>=1.13.1->flair) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from torch>=1.13.1->flair) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from torch>=1.13.1->flair) (3.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.1->flair) (1.3.0)
# Collecting accelerate>=0.26.0 (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair)
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: psutil in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0->transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (7.2.2)
# Requirement already satisfied: click==8.3.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from wikipedia-api>=0.5.7->flair) (8.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from beautifulsoup4->gdown>=4.4.0->flair) (2.8.3)
# Collecting sortedcontainers (from intervaltree->bioc<3.0.0,>=2.0.0->flair)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/katinkakurz/projects/Thesis/.venv/lib/python3.12/site-packages (from jinja2->mpld3>=0.3->flair) (3.0.3)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown>=4.4.0->flair)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Downloading flair-0.15.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.1 MB/s  0:00:00
# Downloading bioc-2.1-py3-none-any.whl (33 kB)
# Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 29.4 MB/s  0:00:00m0:00:010:01
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 19.7 MB/s  0:00:00
# Downloading boto3-1.42.70-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.70-py3-none-any.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 29.0 MB/s  0:00:00 eta 0:00:01
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading wrapt-2.1.2-cp312-cp312-macosx_11_0_arm64.whl (61 kB)
# Using cached ftfy-6.3.1-py3-none-any.whl (44 kB)
# Downloading gdown-5.2.1-py3-none-any.whl (18 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 24.5 MB/s  0:00:00 eta 0:00:01
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading mpld3-0.5.12-py3-none-any.whl (203 kB)
# Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Downloading sentencepiece-0.2.1-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.5 MB/s  0:00:00
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Downloading transformer_smaller_training_vocab-0.4.2-py3-none-any.whl (14 kB)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Downloading wikipedia_api-0.10.2-py3-none-any.whl (22 kB)
# Downloading intervaltree-3.2.1-py2.py3-none-any.whl (25 kB)
# Downloading protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: pptree, sqlitedict, docopt
#   Building wheel for pptree (pyproject.toml) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4640 sha256=7dafeaa43e003177e6dc8018cfd9e7b5914e3b46566120f54a191fc5399f02ab
#   Stored in directory: /Users/katinkakurz/Library/Caches/pip/wheels/b0/2d/de/37058114a8f07cfec75747cb46b864bc5c71b0e9e0e4cd0acd
#   Building wheel for sqlitedict (pyproject.toml) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16955 sha256=28727527cb7856673aab9e93d0b994e491a887b1c14fe788b6476bcbc7d47792
#   Stored in directory: /Users/katinkakurz/Library/Caches/pip/wheels/7a/6f/21/fc016aef45ffcabe27129a2252f061387cbf278d2086225a64
#   Building wheel for docopt (pyproject.toml) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13782 sha256=78a2d0075d3878d52dda95e1c7dd145ed9f0c839e01b72472f5ead15424ae8a1
#   Stored in directory: /Users/katinkakurz/Library/Caches/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built pptree sqlitedict docopt
# Installing collected packages: sqlitedict, sortedcontainers, pptree, docopt, wrapt, tabulate, sentencepiece, segtok, PySocks, protobuf, more-itertools, lxml, langdetect, jsonlines, jmespath, intervaltree, ftfy, conllu, wikipedia-api, huggingface-hub, deprecated, botocore, bioc, s3transfer, pytorch-revgrad, mpld3, gdown, accelerate, transformers, boto3, transformer-smaller-training-vocab, flair
#   Attempting uninstall: huggingface-hub━━━━━━━━━━━━━━━━━━━ 16/32 [ftfy]
#     Found existing installation: huggingface_hub 1.6.0━━━━━━━━ 16/32 [ftfy]
#     Uninstalling huggingface_hub-1.6.0:━━━━━━━━━━━━━━━━━━━ 16/32 [ftfy]
#       Successfully uninstalled huggingface_hub-1.6.0━━━━━━━━━━ 16/32 [ftfy]
#   Attempting uninstall: transformers━━━━━╸━━━━━━ 27/32 [accelerate]-hub]
#     Found existing installation: transformers 5.3.0━━━━━━ 27/32 [accelerate]
#     Uninstalling transformers-5.3.0:━╸━━━━━━ 27/32 [accelerate]
#       Successfully uninstalled transformers-5.3.090m╺━━━━ 28/32 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32/32 [flair]m31/32 [flair]ormers]
# Successfully installed PySocks-1.7.1 accelerate-1.13.0 bioc-2.1 boto3-1.42.70 botocore-1.42.70 conllu-4.5.3 deprecated-1.3.1 docopt-0.6.2 flair-0.15.1 ftfy-6.3.1 gdown-5.2.1 huggingface-hub-0.36.2 intervaltree-3.2.1 jmespath-1.1.0 jsonlines-4.0.0 langdetect-1.0.9 lxml-6.0.2 more-itertools-10.8.0 mpld3-0.5.12 pptree-3.1 protobuf-7.34.0 pytorch-revgrad-0.2.0 s3transfer-0.16.0 segtok-1.5.11 sentencepiece-0.2.1 sortedcontainers-2.4.0 sqlitedict-2.1.0 tabulate-0.10.0 transformer-smaller-training-vocab-0.4.2 transformers-4.57.6 wikipedia-api-0.10.2 wrapt-2.1.2

# %%
from flair.models import SequenceTagger
from flair.splitter import SegtokSentenceSplitter

MODEL_NAME = "flair/ner-german-large"
tagger = SequenceTagger.load(MODEL_NAME)
splitter = SegtokSentenceSplitter()

print(f"Loaded model: {MODEL_NAME}")
# Out:
# pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 2026-03-18 20:28:21,664 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, B-PER, E-PER, S-LOC, B-MISC, I-MISC, E-MISC, S-PER, B-ORG, E-ORG, S-ORG, I-ORG, B-LOC, E-LOC, S-MISC, I-PER, I-LOC, <START>, <STOP>
# Loaded model: flair/ner-german-large

# %% [markdown]
# ## Step 3: Run NER on the corpus
#
# Each article is split into sentences first. Then the model predicts NER tags for those sentences. The extracted entity spans are stored back on article level.

# %%
import os
import torch
import flair

# Allow fallback to CPU for ops not implemented on MPS
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

if torch.backends.mps.is_available():
    flair.device = torch.device("mps")
    device_name = "MPS"
elif torch.cuda.is_available():
    flair.device = torch.device("cuda")
    device_name = "CUDA"
else:
    flair.device = torch.device("cpu")
    device_name = "CPU"

# Reload model so it is placed on the selected device
tagger = SequenceTagger.load(MODEL_NAME)
tagger.to(flair.device)

print(f"Using device: {device_name} ({flair.device})")
print(f"Model loaded: {MODEL_NAME}")
# Out:
# 2026-03-21 13:46:00,254 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, B-PER, E-PER, S-LOC, B-MISC, I-MISC, E-MISC, S-PER, B-ORG, E-ORG, S-ORG, I-ORG, B-LOC, E-LOC, S-MISC, I-PER, I-LOC, <START>, <STOP>
# Using device: MPS (mps)
# Model loaded: flair/ner-german-large

# %%
KEEP_LABELS = {"PER", "ORG", "LOC"}
MIN_SCORE = 0.85

def extract_entities(text):
    if not isinstance(text, str) or not text.strip():
        return []

    sentences = splitter.split(text)
    if not sentences:
        return []

    tagger.predict(sentences, mini_batch_size=1)

    entities = []
    for sentence in sentences:
        for span in sentence.get_spans("ner"):
            label = span.tag
            score = float(span.score)

            if label not in KEEP_LABELS:
                continue
            if score < MIN_SCORE:
                continue

            entities.append(
                {
                    "entity_raw": span.text,
                    "entity": span.text,
                    "label": label,
                    "score": score,
                    # keep start/end only if you really need them later
                    # "start": sentence.start_position + span.start_position,
                    # "end": sentence.start_position + span.end_position,
                }
            )

    return entities

# %%
# NER on texts

all_entities = []
for idx, text in enumerate(run_df["document_text"], start=1):
    all_entities.append(extract_entities(text))
    if idx % 100 == 0 or idx == len(run_df):
        print(f"Processed {idx}/{len(run_df)} unique texts")

run_df["entities"] = all_entities

work = work.drop(columns=["entities"], errors="ignore").merge(
    run_df[["doc_hash", "entities"]],
    on="doc_hash",
    how="left",
)

work["entity_count"] = work["entities"].str.len()
# Out:
# Processed 100/20426 unique texts
# Processed 200/20426 unique texts
# Processed 300/20426 unique texts
# Processed 400/20426 unique texts
# Processed 500/20426 unique texts
# Processed 600/20426 unique texts
# Processed 700/20426 unique texts
# Processed 800/20426 unique texts
# Processed 900/20426 unique texts
# Processed 1000/20426 unique texts
# Processed 1100/20426 unique texts
# Processed 1200/20426 unique texts
# Processed 1300/20426 unique texts
# Processed 1400/20426 unique texts
# Processed 1500/20426 unique texts
# Processed 1600/20426 unique texts
# Processed 1700/20426 unique texts
# Processed 1800/20426 unique texts
# Processed 1900/20426 unique texts
# Processed 2000/20426 unique texts
# Processed 2100/20426 unique texts
# Processed 2200/20426 unique texts
# Processed 2300/20426 unique texts
# Processed 2400/20426 unique texts
# Processed 2500/20426 unique texts
# Processed 2600/20426 unique texts
# Processed 2700/20426 unique texts
# Processed 2800/20426 unique texts
# Processed 2900/20426 unique texts
# Processed 3000/20426 unique texts
# Processed 3100/20426 unique texts
# Processed 3200/20426 unique texts
# Processed 3300/20426 unique texts
# Processed 3400/20426 unique texts
# Processed 3500/20426 unique texts
# Processed 3600/20426 unique texts
# Processed 3700/20426 unique texts
# Processed 3800/20426 unique texts
# Processed 3900/20426 unique texts
# Processed 4000/20426 unique texts
# Processed 4100/20426 unique texts
# Processed 4200/20426 unique texts
# Processed 4300/20426 unique texts
# Processed 4400/20426 unique texts
# Processed 4500/20426 unique texts
# Processed 4600/20426 unique texts
# Processed 4700/20426 unique texts
# Processed 4800/20426 unique texts
# Processed 4900/20426 unique texts
# Processed 5000/20426 unique texts
# Processed 5100/20426 unique texts
# Processed 5200/20426 unique texts
# Processed 5300/20426 unique texts
# Processed 5400/20426 unique texts
# Processed 5500/20426 unique texts
# Processed 5600/20426 unique texts
# Processed 5700/20426 unique texts
# Processed 5800/20426 unique texts
# Processed 5900/20426 unique texts
# Processed 6000/20426 unique texts
# Processed 6100/20426 unique texts
# Processed 6200/20426 unique texts
# Processed 6300/20426 unique texts
# Processed 6400/20426 unique texts
# Processed 6500/20426 unique texts
# Processed 6600/20426 unique texts
# Processed 6700/20426 unique texts
# Processed 6800/20426 unique texts
# Processed 6900/20426 unique texts
# Processed 7000/20426 unique texts
# Processed 7100/20426 unique texts
# Processed 7200/20426 unique texts
# Processed 7300/20426 unique texts
# Processed 7400/20426 unique texts
# Processed 7500/20426 unique texts
# Processed 7600/20426 unique texts
# Processed 7700/20426 unique texts
# Processed 7800/20426 unique texts
# Processed 7900/20426 unique texts
# Processed 8000/20426 unique texts
# Processed 8100/20426 unique texts
# Processed 8200/20426 unique texts
# Processed 8300/20426 unique texts
# Processed 8400/20426 unique texts
# Processed 8500/20426 unique texts
# Processed 8600/20426 unique texts
# Processed 8700/20426 unique texts
# Processed 8800/20426 unique texts
# Processed 8900/20426 unique texts
# Processed 9000/20426 unique texts
# Processed 9100/20426 unique texts
# Processed 9200/20426 unique texts
# Processed 9300/20426 unique texts
# Processed 9400/20426 unique texts
# Processed 9500/20426 unique texts
# Processed 9600/20426 unique texts
# Processed 9700/20426 unique texts
# Processed 9800/20426 unique texts
# Processed 9900/20426 unique texts
# Processed 10000/20426 unique texts
# Processed 10100/20426 unique texts
# Processed 10200/20426 unique texts
# Processed 10300/20426 unique texts
# Processed 10400/20426 unique texts
# Processed 10500/20426 unique texts
# Processed 10600/20426 unique texts
# Processed 10700/20426 unique texts
# Processed 10800/20426 unique texts
# Processed 10900/20426 unique texts
# Processed 11000/20426 unique texts
# Processed 11100/20426 unique texts
# Processed 11200/20426 unique texts
# Processed 11300/20426 unique texts
# Processed 11400/20426 unique texts
# Processed 11500/20426 unique texts
# Processed 11600/20426 unique texts
# Processed 11700/20426 unique texts
# Processed 11800/20426 unique texts
# Processed 11900/20426 unique texts
# Processed 12000/20426 unique texts
# Processed 12100/20426 unique texts
# Processed 12200/20426 unique texts
# Processed 12300/20426 unique texts
# Processed 12400/20426 unique texts
# Processed 12500/20426 unique texts
# Processed 12600/20426 unique texts
# Processed 12700/20426 unique texts
# Processed 12800/20426 unique texts
# Processed 12900/20426 unique texts
# Processed 13000/20426 unique texts
# Processed 13100/20426 unique texts
# Processed 13200/20426 unique texts
# Processed 13300/20426 unique texts
# Processed 13400/20426 unique texts
# Processed 13500/20426 unique texts
# Processed 13600/20426 unique texts
# Processed 13700/20426 unique texts
# Processed 13800/20426 unique texts
# Processed 13900/20426 unique texts
# Processed 14000/20426 unique texts
# Processed 14100/20426 unique texts
# Processed 14200/20426 unique texts
# Processed 14300/20426 unique texts
# Processed 14400/20426 unique texts
# Processed 14500/20426 unique texts
# Processed 14600/20426 unique texts
# Processed 14700/20426 unique texts
# Processed 14800/20426 unique texts
# Processed 14900/20426 unique texts
# Processed 15000/20426 unique texts
# Processed 15100/20426 unique texts
# Processed 15200/20426 unique texts
# Processed 15300/20426 unique texts
# Processed 15400/20426 unique texts
# Processed 15500/20426 unique texts
# Processed 15600/20426 unique texts
# Processed 15700/20426 unique texts
# Processed 15800/20426 unique texts
# Processed 15900/20426 unique texts
# Processed 16000/20426 unique texts
# Processed 16100/20426 unique texts
# Processed 16200/20426 unique texts
# Processed 16300/20426 unique texts
# Processed 16400/20426 unique texts
# Processed 16500/20426 unique texts
# Processed 16600/20426 unique texts
# Processed 16700/20426 unique texts
# Processed 16800/20426 unique texts
# Processed 16900/20426 unique texts
# Processed 17000/20426 unique texts
# Processed 17100/20426 unique texts
# Processed 17200/20426 unique texts
# Processed 17300/20426 unique texts
# Processed 17400/20426 unique texts
# Processed 17500/20426 unique texts
# Processed 17600/20426 unique texts
# Processed 17700/20426 unique texts
# Processed 17800/20426 unique texts
# Processed 17900/20426 unique texts
# Processed 18000/20426 unique texts
# Processed 18100/20426 unique texts
# Processed 18200/20426 unique texts
# Processed 18300/20426 unique texts
# Processed 18400/20426 unique texts
# Processed 18500/20426 unique texts
# Processed 18600/20426 unique texts
# Processed 18700/20426 unique texts
# Processed 18800/20426 unique texts
# Processed 18900/20426 unique texts
# Processed 19000/20426 unique texts
# Processed 19100/20426 unique texts
# Processed 19200/20426 unique texts
# Processed 19300/20426 unique texts
# Processed 19400/20426 unique texts
# Processed 19500/20426 unique texts
# Processed 19600/20426 unique texts
# Processed 19700/20426 unique texts
# Processed 19800/20426 unique texts
# Processed 19900/20426 unique texts
# Processed 20000/20426 unique texts
# Processed 20100/20426 unique texts
# Processed 20200/20426 unique texts
# Processed 20300/20426 unique texts
# Processed 20400/20426 unique texts
# Processed 20426/20426 unique texts

# %%
#Normalize Entity String list after NER


SURFACE_ALIAS_MAP = {
    # spelling / orthography variants
    "selenskij": "Selenskyj",
    "selenskijs": "Selenskyj",
    "selensky": "Selenskyj",
    "selenskys": "Selenskyj",
    "selenskyjs": "Selenskyj",
    "selenski": "Selenskyj",
    "weissrussland": "Weißrussland",
    "weissrusslands": "Weißrussland",
    "von der leyen": "Von der Leyen",
    "ursula von der leyen": "Ursula von der Leyen",
    # German case-inflected multiword entities
    "europäischen union": "Europäische Union",
    "nahen osten": "Naher Osten",
    "nahen ostens": "Naher Osten",
    "weißen haus": "Weißes Haus",
}

# Use this only for HIGH-PRECISION people that are unambiguous in your corpus.
PERSON_CANONICAL_MAP = {
    "trump": "Donald Trump",
    "donald trump": "Donald Trump",
    "merz": "Friedrich Merz",
    "friedrich merz": "Friedrich Merz",
    "habeck": "Robert Habeck",
    "robert habeck": "Robert Habeck",
    "putin": "Wladimir Putin",
    "wladimir putin": "Wladimir Putin",
    "musk": "Elon Musk",
    "elon musk": "Elon Musk",
    "selenskyj": "Wolodymyr Selenskyj",
    "wolodymyr selenskyj": "Wolodymyr Selenskyj",
}

BLOCKLIST = {"i", "j", "l", "x"}
NO_STRIP_FINAL_S = {"Hamas", "Reuters", "Focus", "Taurus"}

def normalize_entity_surface(text: str) -> str:
    text = normalize_unicode(text)
    text = re.sub(r"\s+", " ", text).strip()
    text = text.strip(" \"'.,;:!?()[]{}")
    return text

def strip_german_genitive(entity: str, label: str) -> str:
    # remove trailing apostrophe forms: Merz' -> Merz
    entity = re.sub(r"[']+$", "", entity).strip()

    # remove trailing genitive s only for PER / LOC
    # this catches Trump/Trumps, Habeck/Habecks, Israel/Israels, Russland/Russlands
    if (
        label in {"PER", "LOC"}
        and len(entity) >= 5
        and entity.endswith("s")
        and not entity.isupper()
        and entity not in NO_STRIP_FINAL_S
    ):
        entity = entity[:-1]

    return entity

def normalize_entity(entity: str, label: str = "") -> str | None:
    entity = normalize_entity_surface(entity)

    if not entity or len(entity) < 2:
        return None
    if entity.casefold() in BLOCKLIST:
        return None

    entity = strip_german_genitive(entity, label)

    surface_match = SURFACE_ALIAS_MAP.get(entity.casefold())
    if surface_match:
        entity = surface_match

    if label == "PER":
        person_match = PERSON_CANONICAL_MAP.get(entity.casefold())
        if person_match:
            entity = person_match

    entity = strip_german_genitive(entity, label)

    if not entity or len(entity) < 2:
        return None
    if entity.casefold() in BLOCKLIST:
        return None

    return entity

def expand_person_surnames_within_doc(entity_list: list[dict]) -> list[dict]:
    # If a document contains both "Donald Trump" and "Trump",
    # collapse the short form to the full form within that document only.
    surname_to_full = defaultdict(set)

    for e in entity_list:
        if e.get("label") != "PER":
            continue
        parts = e.get("entity", "").split()
        if len(parts) >= 2:
            surname_to_full[parts[-1].casefold()].add(e["entity"])

    expanded = []
    for e in entity_list:
        item = dict(e)
        if item.get("label") == "PER":
            candidates = surname_to_full.get(item["entity"].casefold(), set())
            if len(candidates) == 1:
                item["entity"] = next(iter(candidates))
        expanded.append(item)

    return expanded

def normalize_entity_list(entity_list: list[dict]) -> list[dict]:
    cleaned = []

    for e in entity_list or []:
        canonical = normalize_entity(e.get("entity", ""), e.get("label", ""))
        if canonical is None:
            continue

        item = dict(e)
        item["entity"] = canonical
        cleaned.append(item)

    cleaned = expand_person_surnames_within_doc(cleaned)
    return cleaned

work["entities"] = work["entities"].apply(normalize_entity_list)
work["entity_count"] = work["entities"].str.len()

print("Normalization complete.")
# Out:
# Normalization complete.

# %%
#Summary Table

mentions = (
    work[["row_id", "source", "entities"]]
    .explode("entities")
    .dropna(subset=["entities"])
    .reset_index(drop=True)
)

entity_parts = mentions["entities"].apply(pd.Series)
mentions = pd.concat([mentions.drop(columns="entities"), entity_parts], axis=1)

mentions["entity"] = mentions["entity"].fillna("").astype(str).str.strip()
mentions = mentions[mentions["entity"] != ""].copy()

entity_summary = (
    mentions.groupby(["entity", "label"])
    .agg(
        mentions=("entity", "size"),
        documents=("row_id", "nunique"),
        sources=("source", "nunique"),
        mean_score=("score", "mean"),
    )
    .sort_values(["documents", "mentions"], ascending=False)
    .reset_index()
)

display(entity_summary.head(50))
# Out:
#                  entity label  mentions  documents  sources  mean_score
# 0          Donald Trump   PER      1138       1136        7    0.999936
# 1           Deutschland   LOC       798        794        7    0.999996
# 2              Russland   LOC       764        761        7    0.999986
# 3        Friedrich Merz   PER       697        695        7    0.999933
# 4                   AfD   ORG       613        602        7    0.999631
# 5                   USA   LOC       595        595        7    0.999446
# 6               Ukraine   LOC       523        523        7    0.999996
# 7                    EU   ORG       359        359        7    0.994774
# 8        Wladimir Putin   PER       351        351        7    0.999976
# 9                Europa   LOC       345        342        7    0.999553
# 10               Israel   LOC       317        316        7    0.999993
# 11  Wolodymyr Selenskyj   PER       316        316        7    0.999986
# 12               Berlin   LOC       273        269        7    0.999991
# 13                China   LOC       263        261        6    0.999993
# 14                 NIUS   ORG       227        222        1    0.999717
# 15                  SPD   ORG       214        213        6    0.999993
# 16                  CDU   ORG       213        213        6    0.999991
# 17            Venezuela   LOC       188        188        7    0.999997
# 18                 Kiew   LOC       185        184        6    0.999991
# 19                 Iran   LOC       163        162        7    0.999997
# 20               Moskau   LOC       151        151        7    0.999994
# 21                Polen   LOC       134        134        7    0.999991
# 22           Frankreich   LOC       127        126        7    0.999997
# 23           Washington   LOC       106        106        7    0.999953
# 24                 Gaza   LOC       102        102        7    0.998700
# 25         Charlie Kirk   PER        99         99        7    0.999997
# 26               Indien   LOC        94         93        5    0.999998
# 27              Brüssel   LOC        93         93        7    0.999994
# 28             Grönland   LOC        93         93        7    0.999995
# 29                   EU   LOC        90         90        7    0.976898
# 30        Von der Leyen   PER        85         85        7    0.999967
# 31                 NATO   ORG        84         83        6    0.999988
# 32                  ZDF   ORG        81         81        5    0.999561
# 33                Hamas   ORG        81         80        5    0.999953
# 34               Macron   PER        79         79        6    0.999961
# 35              Schweiz   LOC        78         78        6    0.999994
# 36                Union   ORG        75         75        6    0.995491
# 37               Ungarn   LOC        74         74        6    0.999996
# 38               Maduro   PER        73         73        6    0.999923
# 39            Netanjahu   PER        73         73        6    0.999980
# 40             Wadephul   PER        73         73        7    0.999402
# 41            Klingbeil   PER        68         68        5    0.996142
# 42               Merkel   PER        66         66        7    0.999950
# 43               Gießen   LOC        65         65        5    0.999947
# 44                  CSU   ORG        63         63        6    0.999992
# 45            Elon Musk   PER        61         61        7    0.999959
# 46               Weimer   PER        62         60        6    0.996890
# 47            Bundestag   ORG        60         60        6    0.986177
# 48                Söder   PER        58         58        6    0.999129
# 49               Syrien   LOC        55         55        6    0.999997

# %% [markdown]
# #### Save Results

# %%
all_entities = (
    mentions.groupby("entity")
    .size()
    .reset_index(name="count")
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)

all_entities.to_csv("all_entities_counts.csv", index=False, encoding="utf-8")
print("Saved to all_entities_counts.csv")
# Out:
# Saved to all_entities_counts.csv
